# %%
import pandas as pd
from scipy import stats
from statistics import mean
from datetime import datetime as DateTime
import yfinance as yf
import pytickersymbols as pts
import stocks_utils as sou

# %% [markdown]
# ## Acquiring information about stocks

# %%
stock_data = pts.PyTickerSymbols()

us30_stocks = stock_data.get_stocks_by_index('DOW JONES')
nasdaq_stocks = stock_data.get_stocks_by_index('NASDAQ 100')
us500_stocks = stock_data.get_stocks_by_index('S&P 500')
uk100_stocks = stock_data.get_stocks_by_index('FTSE 100')
eu50_stocks = stock_data.get_stocks_by_index('EURO STOXX 50')

market_stocks = list(us30_stocks) + list(nasdaq_stocks) + list(us500_stocks) + list(uk100_stocks) + list(eu50_stocks)

excluded_industries = ['Online gambling','Healthcare','Managed Health care','Banking & Investment Services','Metals & Mining','Metal','Insurance','Commercial REITs','Specialized REITs','Financial services','Real Estate','Casinos & Gaming','Fossil Fuels','Defense','Cosmetics','defense','Life insurance','Real estate investment trust']

# excluded_sectors = ['Biotechnology & Medical Research','Online gambling','Pharmaceuticals','Healthcare','Managed Health care','Medical Equipment','Banking & Investment Services','Medical Equipment, Supplies & Distribution','Metals & Mining','Metal','Insurance','Commercial REITs','Specialized REITs','Financial services','Beverages','Food & Beverages','Real Estate','Casinos & Gaming','Fossil Fuels','Defense','Restaurants']

stocks_list = []
for market_stock in market_stocks:
    try:
        ignore = False
        for market_industry in market_stock['industries']:
            if(market_industry in excluded_industries):
                ignore = True
                break
            
        if(ignore):
            continue

        stock_symbol = market_stock['symbol']
        symbols = market_stock['symbols']

        symbol_google = None
        symbol_yahoo = None
        for symbol in symbols:
            if(symbol['google'].endswith(f':{stock_symbol}')):
                symbol_google = symbol['google']
                symbol_yahoo = symbol['yahoo']
                break

        if(symbol_yahoo is None):
            continue

        item = {
            'Company': market_stock['name'],
            'Symbol': stock_symbol,
            'Symbol_Google': symbol_google,
            'Symbol_Yahoo': symbol_yahoo,
            'Country': market_stock['country'],
            'Indices': ', '.join(market_stock['indices']),
            'Industries': ', '.join(market_stock['industries'])
        }

        stocks_list.append(item)
    except:
        pass

stocks = pd.DataFrame(stocks_list, columns=['Company','Symbol','Symbol_Google','Symbol_Yahoo','Country','Indices','Industries'])
stocks
# Out:
#                              Company Symbol Symbol_Google Symbol_Yahoo  \
# 0                         3M Company    MMM       FRA:MMM        MMM.F
# 1                         Apple Inc.   AAPL   NASDAQ:AAPL         AAPL
# 2                 The Boeing Company     BA       NYSE:BA           BA
# 3                   Caterpillar Inc.    CAT      NYSE:CAT          CAT
# 4                 Cisco Systems Inc.   CSCO   NASDAQ:CSCO         CSCO
# ..                               ...    ...           ...          ...
# 482              Amadeus IT Group SA    AMS       BME:AMS       AMS.MC
# 483                     Iberdrola SA    IBE       BME:IBE       IBE.MC
# 484  Koninklijke Ahold Delhaize N.V.     AD        AMS:AD        AD.AS
# 485                ASML Holding N.V.   ASML   NASDAQ:ASML         ASML
# 486                       Eni S.p.A.    ENI       FRA:ENI        ENI.F
#
#            Country                                  Indices  \
# 0    United States              DOW JONES, S&P 100, S&P 500
# 1    United States  DOW JONES, NASDAQ 100, S&P 100, S&P 500
# 2    United States              DOW JONES, S&P 100, S&P 500
# 3    United States              DOW JONES, S&P 100, S&P 500
# 4    United States  DOW JONES, NASDAQ 100, S&P 100, S&P 500
# ..             ...                                      ...
# 482          Spain                   EURO STOXX 50, IBEX 35
# 483          Spain                   EURO STOXX 50, IBEX 35
# 484    Netherlands                       AEX, EURO STOXX 50
# 485    Netherlands           AEX, EURO STOXX 50, NASDAQ 100
# 486          Italy                            EURO STOXX 50
#
#                                             Industries
# 0                Industrials, Industrial Conglomerates
# 1    Computers, Phones & Household Electronics, Tec...
# 2    Industrial Goods, Industrials, Aerospace & Def...
# 3    Industrial Goods, Industrials, Heavy Machinery...
# 4    Technology, Technology Equipment, Communicatio...
# ..                                                 ...
# 482  Technology, Software & IT Services, IT Service...
# 483  Electric Utilities, Electric Utilities & IPPs,...
# 484  Consumer Non-Cyclicals, Food & Drug Retailing,...
# 485  Semiconductor Equipment & Testing, Technology,...
# 486                                        Oil and gas
#
# [487 rows x 7 columns]

# %%
# Some stocks are listed on more than the stock index.
stocks.set_index('Symbol',inplace=True)
stocks = stocks[~stocks.index.duplicated(keep='first')]
stocks
# Out:
#                                 Company Symbol_Google Symbol_Yahoo  \
# Symbol
# MMM                          3M Company       FRA:MMM        MMM.F
# AAPL                         Apple Inc.   NASDAQ:AAPL         AAPL
# BA                   The Boeing Company       NYSE:BA           BA
# CAT                    Caterpillar Inc.      NYSE:CAT          CAT
# CSCO                 Cisco Systems Inc.   NASDAQ:CSCO         CSCO
# ...                                 ...           ...          ...
# AIR                           Airbus SE       FRA:AIR        AIR.F
# AMS                 Amadeus IT Group SA       BME:AMS       AMS.MC
# IBE                        Iberdrola SA       BME:IBE       IBE.MC
# AD      Koninklijke Ahold Delhaize N.V.        AMS:AD        AD.AS
# ENI                          Eni S.p.A.       FRA:ENI        ENI.F
#
#               Country                                  Indices  \
# Symbol
# MMM     United States              DOW JONES, S&P 100, S&P 500
# AAPL    United States  DOW JONES, NASDAQ 100, S&P 100, S&P 500
# BA      United States              DOW JONES, S&P 100, S&P 500
# CAT     United States              DOW JONES, S&P 100, S&P 500
# CSCO    United States  DOW JONES, NASDAQ 100, S&P 100, S&P 500
# ...               ...                                      ...
# AIR       Netherlands              MDAX, EURO STOXX 50, CAC 40
# AMS             Spain                   EURO STOXX 50, IBEX 35
# IBE             Spain                   EURO STOXX 50, IBEX 35
# AD        Netherlands                       AEX, EURO STOXX 50
# ENI             Italy                            EURO STOXX 50
#
#                                                Industries
# Symbol
# MMM                 Industrials, Industrial Conglomerates
# AAPL    Computers, Phones & Household Electronics, Tec...
# BA      Industrial Goods, Industrials, Aerospace & Def...
# CAT     Industrial Goods, Industrials, Heavy Machinery...
# CSCO    Technology, Technology Equipment, Communicatio...
# ...                                                   ...
# AIR     Industrial Goods, Industrials, Aerospace & Def...
# AMS     Technology, Software & IT Services, IT Service...
# IBE     Electric Utilities, Electric Utilities & IPPs,...
# AD      Consumer Non-Cyclicals, Food & Drug Retailing,...
# ENI                                           Oil and gas
#
# [394 rows x 6 columns]

# %% [markdown]
# ## Transforming data for value calculation

# %%
# Defining stocks value scoring dataframe

df_columns = [
    'Company',
    'Symbol',
    'Symbol_Google',
    'Symbol_Yahoo',
    'Description',
    'Country',        
    'Indices',
    'Industries',
    'MarketCap',
    'Y1HighestPriceValue',
    'Y1HighestPriceDate',
    'Currency',
    'PriceToEarningsRatio',
    'PriceToEarningsPercentile',
    'PriceToEarningsInversePercentile',
    'PriceToSalesRatio',
    'PriceToSalesPercentile',
    'PriceToSalesInversePercentile',
    'EV_EBITDA',
    'EV_EBITDAPercentile',
    'EV_R',
    'EV_RPercentile',
    'EV_RInversePercentile',
    'Score_Long',
    'Score_Short'
]

so_dataframe = pd.DataFrame(columns = df_columns)

# Getting fundamental data
i = 0
total_stocks = len(stocks)
errors = 0
for index, stock in stocks.iterrows():
    i+=1
    stock_name = stock['Company']
    symbol = index

    symbol_google = stock['Symbol_Google']
    symbol_yahoo = stock['Symbol_Yahoo']

    print(f'({i}/{total_stocks}) | {symbol} (Google: {symbol_google}, Yahoo: {symbol_yahoo}) | {stock_name}')
    print(f'Retreiving fundamental data from yfinance...')

    try:
        yf_ticker = yf.Ticker(symbol_yahoo)

        day_data = yf_ticker.history(period="1y", interval="1d")
        day_data.dropna(inplace=True)
        day_data.sort_values('High', ascending=False, inplace=True)

        so_dataframe = so_dataframe.append(
            pd.Series([
                stock_name,
                symbol,
                symbol_google,
                symbol_yahoo,
                yf_ticker.info['longBusinessSummary'],
                stock['Country'],
                stock['Indices'],
                stock['Industries'],
                yf_ticker.info['marketCap'],
                day_data.iloc[0]['High'],
                day_data.index[0].strftime('%Y-%m-%d'),
                yf_ticker.info['currency'],
                yf_ticker.info['trailingPE'],
                'N/A',
                'N/A',
                yf_ticker.info['priceToSalesTrailing12Months'],
                'N/A',
                'N/A',
                yf_ticker.info['enterpriseToEbitda'],
                'N/A',
                yf_ticker.info['enterpriseToRevenue'],
                'N/A',
                'N/A',
                'N/A',
                'N/A'
            ], index = df_columns),
            ignore_index = True)

    except Exception as error:
        print('ERROR:', error)
        errors+=1
        print('An error occurred while trying to get the information!')
        
    print()

initial_count = len(so_dataframe)

# Dealing With Missing Data
so_dataframe = so_dataframe[so_dataframe['Industries']!=''].dropna()
# Out:
# (1/394) | MMM (Google: FRA:MMM, Yahoo: MMM.F) | 3M Company
# Retreiving fundamental data from yfinance...
#
# (2/394) | AAPL (Google: NASDAQ:AAPL, Yahoo: AAPL) | Apple Inc.
# Retreiving fundamental data from yfinance...
#
# (3/394) | BA (Google: NYSE:BA, Yahoo: BA) | The Boeing Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (4/394) | CAT (Google: NYSE:CAT, Yahoo: CAT) | Caterpillar Inc.
# Retreiving fundamental data from yfinance...
#
# (5/394) | CSCO (Google: NASDAQ:CSCO, Yahoo: CSCO) | Cisco Systems Inc.
# Retreiving fundamental data from yfinance...
#
# (6/394) | KO (Google: OTCMKTS:KO, Yahoo: KO) | The Coca-Cola Company
# Retreiving fundamental data from yfinance...
#
# (7/394) | HD (Google: NYSE:HD, Yahoo: HD) | The Home Depot Inc.
# Retreiving fundamental data from yfinance...
#
# (8/394) | IBM (Google: FRA:IBM, Yahoo: IBM.F) | International Business Machines Corporation
# Retreiving fundamental data from yfinance...
#
# (9/394) | INTC (Google: NASDAQ:INTC, Yahoo: INTC) | Intel Corporation
# Retreiving fundamental data from yfinance...
#
# (10/394) | MCD (Google: NYSE:MCD, Yahoo: MCD) | McDonald's Corporation
# Retreiving fundamental data from yfinance...
#
# (11/394) | MSFT (Google: NASDAQ:MSFT, Yahoo: MSFT) | Microsoft Corporation
# Retreiving fundamental data from yfinance...
#
# (12/394) | NKE (Google: FRA:NKE, Yahoo: NKE.F) | NIKE Inc.
# Retreiving fundamental data from yfinance...
#
# (13/394) | PG (Google: NYSE:PG, Yahoo: PG) | The Procter & Gamble Company
# Retreiving fundamental data from yfinance...
#
# (14/394) | VZ (Google: NYSE:VZ, Yahoo: VZ) | Verizon Communications Inc.
# Retreiving fundamental data from yfinance...
#
# (15/394) | V (Google: NYSE:V, Yahoo: V) | Visa Inc.
# Retreiving fundamental data from yfinance...
#
# (16/394) | WMT (Google: FRA:WMT, Yahoo: WMT.F) | Walmart Inc.
# Retreiving fundamental data from yfinance...
#
# (17/394) | WBA (Google: NASDAQ:WBA, Yahoo: WBA) | Walgreens Boots Alliance Inc.
# Retreiving fundamental data from yfinance...
#
# (18/394) | DIS (Google: OTCMKTS:DIS, Yahoo: DIS) | The Walt Disney Company
# Retreiving fundamental data from yfinance...
#
# (19/394) | HON (Google: NYSE:HON, Yahoo: HON) | Honeywell International Inc.
# Retreiving fundamental data from yfinance...
#
# (20/394) | CRM (Google: NYSE:CRM, Yahoo: CRM) | salesforce.com Inc.
# Retreiving fundamental data from yfinance...
#
# (21/394) | DOW (Google: NYSE:DOW, Yahoo: DOW) | Dow Inc.
# Retreiving fundamental data from yfinance...
#
# (22/394) | ATVI (Google: NASDAQ:ATVI, Yahoo: ATVI) | Activision Blizzard Inc.
# Retreiving fundamental data from yfinance...
#
# (23/394) | ADBE (Google: NASDAQ:ADBE, Yahoo: ADBE) | Adobe Inc.
# Retreiving fundamental data from yfinance...
#
# (24/394) | GOOGL (Google: NASDAQ:GOOGL, Yahoo: GOOGL) | Alphabet Inc.
# Retreiving fundamental data from yfinance...
#
# (25/394) | AMZN (Google: NASDAQ:AMZN, Yahoo: AMZN) | Amazon.com Inc.
# Retreiving fundamental data from yfinance...
#
# (26/394) | ADI (Google: NASDAQ:ADI, Yahoo: ADI) | Analog Devices Inc.
# Retreiving fundamental data from yfinance...
#
# (27/394) | AMAT (Google: NASDAQ:AMAT, Yahoo: AMAT) | Applied Materials Inc.
# Retreiving fundamental data from yfinance...
#
# (28/394) | ADSK (Google: NASDAQ:ADSK, Yahoo: ADSK) | Autodesk Inc.
# Retreiving fundamental data from yfinance...
#
# (29/394) | ADP (Google: FRA:ADP, Yahoo: ADP.F) | Automatic Data Processing Inc.
# Retreiving fundamental data from yfinance...
#
# (30/394) | BIDU (Google: NASDAQ:BIDU, Yahoo: BIDU) | Baidu Inc.
# Retreiving fundamental data from yfinance...
#
# (31/394) | CHTR (Google: NASDAQ:CHTR, Yahoo: CHTR) | Charter Communications Inc.
# Retreiving fundamental data from yfinance...
#
# (32/394) | CHKP (Google: NASDAQ:CHKP, Yahoo: CHKP) | Check Point Software Technologies Ltd.
# Retreiving fundamental data from yfinance...
#
# (33/394) | CTSH (Google: NASDAQ:CTSH, Yahoo: CTSH) | Cognizant Technology Solutions Corporation
# Retreiving fundamental data from yfinance...
#
# (34/394) | CMCSA (Google: NASDAQ:CMCSA, Yahoo: CMCSA) | Comcast Corporation
# Retreiving fundamental data from yfinance...
#
# (35/394) | COST (Google: NASDAQ:COST, Yahoo: COST) | Costco Wholesale Corporation
# Retreiving fundamental data from yfinance...
#
# (36/394) | CSX (Google: NASDAQ:CSX, Yahoo: CSX) | CSX Corporation
# Retreiving fundamental data from yfinance...
#
# (37/394) | CTRP (Google: NASDAQ:CTRP, Yahoo: CTRP) | Ctrip.com International, Ltd.
# Retreiving fundamental data from yfinance...
# - CTRP: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (38/394) | DLTR (Google: NASDAQ:DLTR, Yahoo: DLTR) | Dollar Tree Inc.
# Retreiving fundamental data from yfinance...
#
# (39/394) | EBAY (Google: NASDAQ:EBAY, Yahoo: EBAY) | eBay Inc.
# Retreiving fundamental data from yfinance...
#
# (40/394) | EA (Google: NASDAQ:EA, Yahoo: EA) | Electronic Arts Inc.
# Retreiving fundamental data from yfinance...
#
# (41/394) | FB (Google: NASDAQ:FB, Yahoo: FB) | Facebook Inc.
# Retreiving fundamental data from yfinance...
#
# (42/394) | FAST (Google: NASDAQ:FAST, Yahoo: FAST) | Fastenal Company
# Retreiving fundamental data from yfinance...
#
# (43/394) | FISV (Google: NASDAQ:FISV, Yahoo: FISV) | Fiserv Inc.
# Retreiving fundamental data from yfinance...
#
# (44/394) | INTU (Google: NASDAQ:INTU, Yahoo: INTU) | Intuit Inc.
# Retreiving fundamental data from yfinance...
#
# (45/394) | JD (Google: NASDAQ:JD, Yahoo: JD) | JD.com Inc.
# Retreiving fundamental data from yfinance...
#
# (46/394) | KHC (Google: NASDAQ:KHC, Yahoo: KHC) | The Kraft Heinz Company
# Retreiving fundamental data from yfinance...
#
# (47/394) | LRCX (Google: NASDAQ:LRCX, Yahoo: LRCX) | Lam Research Corporation
# Retreiving fundamental data from yfinance...
#
# (48/394) | MAR (Google: NASDAQ:MAR, Yahoo: MAR) | Marriott International Inc.
# Retreiving fundamental data from yfinance...
#
# (49/394) | MXIM (Google: NASDAQ:MXIM, Yahoo: MXIM) | Maxim Integrated Products Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (50/394) | MCHP (Google: NASDAQ:MCHP, Yahoo: MCHP) | Microchip Technology Inc.
# Retreiving fundamental data from yfinance...
#
# (51/394) | MU (Google: NASDAQ:MU, Yahoo: MU) | Micron Technology Inc.
# Retreiving fundamental data from yfinance...
#
# (52/394) | MDLZ (Google: NASDAQ:MDLZ, Yahoo: MDLZ) | Mondelez International Inc.
# Retreiving fundamental data from yfinance...
#
# (53/394) | MNST (Google: NASDAQ:MNST, Yahoo: MNST) | Monster Beverage Corporation
# Retreiving fundamental data from yfinance...
#
# (54/394) | NTES (Google: NASDAQ:NTES, Yahoo: NTES) | NetEase Inc.
# Retreiving fundamental data from yfinance...
#
# (55/394) | NFLX (Google: NASDAQ:NFLX, Yahoo: NFLX) | Netflix Inc.
# Retreiving fundamental data from yfinance...
#
# (56/394) | NVDA (Google: NASDAQ:NVDA, Yahoo: NVDA) | NVIDIA Corporation
# Retreiving fundamental data from yfinance...
#
# (57/394) | NXPI (Google: NASDAQ:NXPI, Yahoo: NXPI) | NXP Semiconductors N.V.
# Retreiving fundamental data from yfinance...
#
# (58/394) | ORLY (Google: NASDAQ:ORLY, Yahoo: ORLY) | O'Reilly Automotive Inc.
# Retreiving fundamental data from yfinance...
#
# (59/394) | PCAR (Google: NASDAQ:PCAR, Yahoo: PCAR) | PACCAR Inc
# Retreiving fundamental data from yfinance...
#
# (60/394) | PAYX (Google: NASDAQ:PAYX, Yahoo: PAYX) | Paychex Inc.
# Retreiving fundamental data from yfinance...
#
# (61/394) | PYPL (Google: NASDAQ:PYPL, Yahoo: PYPL) | PayPal Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (62/394) | QCOM (Google: NASDAQ:QCOM, Yahoo: QCOM) | Qualcomm Inc.
# Retreiving fundamental data from yfinance...
#
# (63/394) | ROST (Google: NASDAQ:ROST, Yahoo: ROST) | Ross Stores Inc.
# Retreiving fundamental data from yfinance...
#
# (64/394) | SIRI (Google: NASDAQ:SIRI, Yahoo: SIRI) | Sirius XM Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (65/394) | SWKS (Google: NASDAQ:SWKS, Yahoo: SWKS) | Skyworks Solutions Inc.
# Retreiving fundamental data from yfinance...
#
# (66/394) | SBUX (Google: NASDAQ:SBUX, Yahoo: SBUX) | Starbucks Corporation
# Retreiving fundamental data from yfinance...
#
# (67/394) | TMUS (Google: NASDAQ:TMUS, Yahoo: TMUS) | T-Mobile US Inc.
# Retreiving fundamental data from yfinance...
#
# (68/394) | TSLA (Google: NASDAQ:TSLA, Yahoo: TSLA) | Tesla Inc.
# Retreiving fundamental data from yfinance...
#
# (69/394) | TXN (Google: NASDAQ:TXN, Yahoo: TXN) | Texas Instruments Inc.
# Retreiving fundamental data from yfinance...
#
# (70/394) | VRSK (Google: NASDAQ:VRSK, Yahoo: VRSK) | Verisk Analytics Inc.
# Retreiving fundamental data from yfinance...
#
# (71/394) | XLNX (Google: NASDAQ:XLNX, Yahoo: XLNX) | Xilinx Inc.
# Retreiving fundamental data from yfinance...
#
# (72/394) | BKNG (Google: NASDAQ:BKNG, Yahoo: BKNG) | Booking Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (73/394) | EXC (Google: NYSE:EXC, Yahoo: EXC) | Exelon Corporation
# Retreiving fundamental data from yfinance...
#
# (74/394) | AMD (Google: FRA:AMD, Yahoo: AMD.F) | Advanced Micro Devices Inc.
# Retreiving fundamental data from yfinance...
#
# (75/394) | AEP (Google: FRA:AEP, Yahoo: AEP.F) | American Electric Power Company Inc.
# Retreiving fundamental data from yfinance...
#
# (76/394) | ANSS (Google: NASDAQ:ANSS, Yahoo: ANSS) | ANSYS Inc.
# Retreiving fundamental data from yfinance...
#
# (77/394) | AVGO (Google: NASDAQ:AVGO, Yahoo: AVGO) | Broadcom Inc.
# Retreiving fundamental data from yfinance...
#
# (78/394) | CDNS (Google: NASDAQ:CDNS, Yahoo: CDNS) | Cadence Design Systems Inc.
# Retreiving fundamental data from yfinance...
#
# (79/394) | CTAS (Google: NASDAQ:CTAS, Yahoo: CTAS) | Cintas Corporation
# Retreiving fundamental data from yfinance...
#
# (80/394) | CPRT (Google: NASDAQ:CPRT, Yahoo: CPRT) | Copart Inc.
# Retreiving fundamental data from yfinance...
#
# (81/394) | FOXA (Google: NASDAQ:FOXA, Yahoo: FOXA) | Fox Corporation
# Retreiving fundamental data from yfinance...
#
# (82/394) | KLAC (Google: NASDAQ:KLAC, Yahoo: KLAC) | KLA-Tencor Corporation
# Retreiving fundamental data from yfinance...
#
# (83/394) | SNPS (Google: NASDAQ:SNPS, Yahoo: SNPS) | Synopsys Inc.
# Retreiving fundamental data from yfinance...
#
# (84/394) | VRSN (Google: FRA:VRSN, Yahoo: VRS.F) | VeriSign Inc.
# Retreiving fundamental data from yfinance...
#
# (85/394) | ASML (Google: NASDAQ:ASML, Yahoo: ASML) | ASML Holding N.V.
# Retreiving fundamental data from yfinance...
#
# (86/394) | CDW (Google: NASDAQ:CDW, Yahoo: CDW) | CDW Corporation
# Retreiving fundamental data from yfinance...
#
# (87/394) | DXCM (Google: NASDAQ:DXCM, Yahoo: DXCM) | DexCom, Inc.
# Retreiving fundamental data from yfinance...
#
# (88/394) | PEP (Google: NASDAQ:PEP, Yahoo: PEP) | PepsiCo, Inc.
# Retreiving fundamental data from yfinance...
#
# (89/394) | XEL (Google: NASDAQ:XEL, Yahoo: XEL) | Xcel Energy Inc.
# Retreiving fundamental data from yfinance...
#
# (90/394) | TEAM (Google: NASDAQ:TEAM, Yahoo: TEAM) | Atlassian Corporation Plc
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (91/394) | DOCU (Google: NASDAQ:DOCU, Yahoo: DOCU) | DocuSign, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (92/394) | KDP (Google: NASDAQ:KDP, Yahoo: KDP) | Keurig Dr Pepper Inc.
# Retreiving fundamental data from yfinance...
#
# (93/394) | LULU (Google: NASDAQ:LULU, Yahoo: LULU) | lululemon athletica inc.
# Retreiving fundamental data from yfinance...
#
# (94/394) | MRVL (Google: NASDAQ:MRVL, Yahoo: MRVL) | Marvell Technology Group Ltd.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (95/394) | MTCH (Google: NASDAQ:MTCH, Yahoo: MTCH) | Match Group, Inc.
# Retreiving fundamental data from yfinance...
#
# (96/394) | MELI (Google: NASDAQ:MELI, Yahoo: MELI) | Mercado Libre, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (97/394) | MRNA (Google: NASDAQ:MRNA, Yahoo: MRNA) | Moderna, Inc.
# Retreiving fundamental data from yfinance...
#
# (98/394) | OKTA (Google: NASDAQ:OKTA, Yahoo: OKTA) | Okta, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (99/394) | PTON (Google: NASDAQ:PTON, Yahoo: PTON) | Peloton Interactive, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (100/394) | PDD (Google: NASDAQ:PDD, Yahoo: PDD) | Pinduoduo Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (101/394) | SGEN (Google: NASDAQ:SGEN, Yahoo: SGEN) | Seagen Inc.
# Retreiving fundamental data from yfinance...
#
# (102/394) | SPLK (Google: NASDAQ:SPLK, Yahoo: SPLK) | Splunk Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (103/394) | WDAY (Google: NASDAQ:WDAY, Yahoo: WDAY) | Workday, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (104/394) | ZM (Google: NASDAQ:ZM, Yahoo: ZM) | Zoom Video Communications, Inc.
# Retreiving fundamental data from yfinance...
#
# (105/394) | LIN (Google: FRA:LIN, Yahoo: LIN.F) | Linde PLC
# Retreiving fundamental data from yfinance...
#
# (106/394) | CCL (Google: NYSE:CCL, Yahoo: CCL) | Carnival Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (107/394) | AKAM (Google: NASDAQ:AKAM, Yahoo: AKAM) | Akamai Technologies Inc.
# Retreiving fundamental data from yfinance...
#
# (108/394) | AAL (Google: NASDAQ:AAL, Yahoo: AAL) | American Airlines Group Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (109/394) | CTXS (Google: NASDAQ:CTXS, Yahoo: CTXS) | Citrix Systems Inc.
# Retreiving fundamental data from yfinance...
#
# (110/394) | DISCA (Google: NASDAQ:DISCA, Yahoo: DISCA) | Discovery Inc.
# Retreiving fundamental data from yfinance...
#
# (111/394) | DISH (Google: NASDAQ:DISH, Yahoo: DISH) | DISH Network Corporation
# Retreiving fundamental data from yfinance...
#
# (112/394) | EXPE (Google: NASDAQ:EXPE, Yahoo: EXPE) | Expedia Group Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (113/394) | NTAP (Google: NASDAQ:NTAP, Yahoo: NTAP) | NetApp Inc.
# Retreiving fundamental data from yfinance...
#
# (114/394) | STX (Google: NASDAQ:STX, Yahoo: STX) | Seagate Technology PLC
# Retreiving fundamental data from yfinance...
#
# (115/394) | TSCO (Google: NASDAQ:TSCO, Yahoo: TSCO) | Tractor Supply Company
# Retreiving fundamental data from yfinance...
#
# (116/394) | ULTA (Google: NASDAQ:ULTA, Yahoo: ULTA) | Ulta Beauty Inc.
# Retreiving fundamental data from yfinance...
#
# (117/394) | WDC (Google: FRA:WDC, Yahoo: WDC.F) | Western Digital Corporation
# Retreiving fundamental data from yfinance...
#
# (118/394) | ACN (Google: NYSE:ACN, Yahoo: ACN) | Accenture PLC
# Retreiving fundamental data from yfinance...
#
# (119/394) | MO (Google: NYSE:MO, Yahoo: MO) | Altria Group Inc.
# Retreiving fundamental data from yfinance...
#
# (120/394) | T (Google: NYSE:T, Yahoo: T) | AT&T Inc
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (121/394) | CL (Google: NYSE:CL, Yahoo: CL) | Colgate-Palmolive Company
# Retreiving fundamental data from yfinance...
#
# (122/394) | DUK (Google: NYSE:DUK, Yahoo: DUK) | Duke Energy Corporation
# Retreiving fundamental data from yfinance...
#
# (123/394) | EMR (Google: FRA:EMR, Yahoo: EMR.F) | Emerson Electric Co.
# Retreiving fundamental data from yfinance...
#
# (124/394) | FDX (Google: FRA:FDX, Yahoo: FDX.F) | FedEx Corporation
# Retreiving fundamental data from yfinance...
#
# (125/394) | F (Google: NYSE:F, Yahoo: F) | Ford Motor Company
# Retreiving fundamental data from yfinance...
#
# (126/394) | GE (Google: NYSE:GE, Yahoo: GE) | General Electric Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (127/394) | GM (Google: NYSE:GM, Yahoo: GM) | General Motors Company
# Retreiving fundamental data from yfinance...
#
# (128/394) | LOW (Google: NYSE:LOW, Yahoo: LOW) | Lowe's Companies Inc.
# Retreiving fundamental data from yfinance...
#
# (129/394) | MA (Google: NYSE:MA, Yahoo: MA) | Mastercard Inc.
# Retreiving fundamental data from yfinance...
#
# (130/394) | NEE (Google: NYSE:NEE, Yahoo: NEE) | NextEra Energy Inc.
# Retreiving fundamental data from yfinance...
#
# (131/394) | ORCL (Google: NYSE:ORCL, Yahoo: ORCL) | Oracle Corporation
# Retreiving fundamental data from yfinance...
#
# (132/394) | RTN (Google: NYSE:RTN, Yahoo: RTN) | Raytheon Company
# Retreiving fundamental data from yfinance...
# - RTN: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (133/394) | SO (Google: NYSE:SO, Yahoo: SO) | Southern Company
# Retreiving fundamental data from yfinance...
#
# (134/394) | TGT (Google: NYSE:TGT, Yahoo: TGT) | Target Corporation
# Retreiving fundamental data from yfinance...
#
# (135/394) | UNP (Google: FRA:UNP, Yahoo: UNP.F) | Union Pacific Corporation
# Retreiving fundamental data from yfinance...
#
# (136/394) | UPS (Google: NYSE:UPS, Yahoo: UPS) | United Parcel Service Inc.
# Retreiving fundamental data from yfinance...
#
# (137/394) | AAP (Google: NYSE:AAP, Yahoo: AAP) | Advance Auto Parts Inc.
# Retreiving fundamental data from yfinance...
#
# (138/394) | AES (Google: FRA:AES, Yahoo: AES.F) | The AES Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (139/394) | APD (Google: NYSE:APD, Yahoo: APD) | Air Products and Chemicals Inc.
# Retreiving fundamental data from yfinance...
#
# (140/394) | ALK (Google: FRA:ALK, Yahoo: ALK.F) | Alaska Air Group Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (141/394) | ALB (Google: NYSE:ALB, Yahoo: ALB) | Albemarle Corporation
# Retreiving fundamental data from yfinance...
#
# (142/394) | ALLE (Google: NYSE:ALLE, Yahoo: ALLE) | Allegion PLC
# Retreiving fundamental data from yfinance...
#
# (143/394) | AEE (Google: NYSE:AEE, Yahoo: AEE) | Ameren Corporation
# Retreiving fundamental data from yfinance...
#
# (144/394) | AWK (Google: NYSE:AWK, Yahoo: AWK) | American Water Works Company Inc.
# Retreiving fundamental data from yfinance...
#
# (145/394) | ABC (Google: NYSE:ABC, Yahoo: ABC) | AmerisourceBergen Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (146/394) | AME (Google: NYSE:AME, Yahoo: AME) | AMETEK Inc.
# Retreiving fundamental data from yfinance...
#
# (147/394) | APH (Google: NYSE:APH, Yahoo: APH) | Amphenol Corporation
# Retreiving fundamental data from yfinance...
#
# (148/394) | AOS (Google: NYSE:AOS, Yahoo: AOS) | A. O. Smith Corporation
# Retreiving fundamental data from yfinance...
#
# (149/394) | APTV (Google: NYSE:APTV, Yahoo: APTV) | Aptiv PLC
# Retreiving fundamental data from yfinance...
#
# (150/394) | ADM (Google: FRA:ADM, Yahoo: ADM.F) | Archer-Daniels-Midland Company
# Retreiving fundamental data from yfinance...
#
# (151/394) | ANET (Google: NYSE:ANET, Yahoo: ANET) | Arista Networks Inc.
# Retreiving fundamental data from yfinance...
#
# (152/394) | ATO (Google: NYSE:ATO, Yahoo: ATO) | Atmos Energy Corporation
# Retreiving fundamental data from yfinance...
#
# (153/394) | AZO (Google: NYSE:AZO, Yahoo: AZO) | AutoZone Inc.
# Retreiving fundamental data from yfinance...
#
# (154/394) | AVY (Google: NYSE:AVY, Yahoo: AVY) | Avery Dennison Corporation
# Retreiving fundamental data from yfinance...
#
# (155/394) | BLL (Google: NYSE:BLL, Yahoo: BLL) | Ball Corporation
# Retreiving fundamental data from yfinance...
#
# (156/394) | BBY (Google: NYSE:BBY, Yahoo: BBY) | Best Buy Co. Inc.
# Retreiving fundamental data from yfinance...
#
# (157/394) | BWA (Google: NYSE:BWA, Yahoo: BWA) | BorgWarner Inc.
# Retreiving fundamental data from yfinance...
#
# (158/394) | BR (Google: NYSE:BR, Yahoo: BR) | Broadridge Financial Solutions Inc.
# Retreiving fundamental data from yfinance...
#
# (159/394) | CHRW (Google: NASDAQ:CHRW, Yahoo: CHRW) | C.H. Robinson Worldwide Inc.
# Retreiving fundamental data from yfinance...
#
# (160/394) | CPB (Google: NYSE:CPB, Yahoo: CPB) | Campbell Soup Company
# Retreiving fundamental data from yfinance...
#
# (161/394) | CAH (Google: NYSE:CAH, Yahoo: CAH) | Cardinal Health Inc.
# Retreiving fundamental data from yfinance...
#
# (162/394) | KMX (Google: NYSE:KMX, Yahoo: KMX) | CarMax Inc.
# Retreiving fundamental data from yfinance...
#
# (163/394) | CE (Google: NYSE:CE, Yahoo: CE) | Celanese Corporation
# Retreiving fundamental data from yfinance...
#
# (164/394) | CNP (Google: NYSE:CNP, Yahoo: CNP) | CenterPoint Energy Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (165/394) | CF (Google: NYSE:CF, Yahoo: CF) | CF Industries Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (166/394) | CMG (Google: NYSE:CMG, Yahoo: CMG) | Chipotle Mexican Grill Inc.
# Retreiving fundamental data from yfinance...
#
# (167/394) | CHD (Google: NYSE:CHD, Yahoo: CHD) | Church & Dwight Co. Inc.
# Retreiving fundamental data from yfinance...
#
# (168/394) | CLX (Google: NYSE:CLX, Yahoo: CLX) | The Clorox Company
# Retreiving fundamental data from yfinance...
#
# (169/394) | CMS (Google: NYSE:CMS, Yahoo: CMS) | CMS Energy Corporation
# Retreiving fundamental data from yfinance...
#
# (170/394) | CAG (Google: NYSE:CAG, Yahoo: CAG) | Conagra Brands Inc.
# Retreiving fundamental data from yfinance...
#
# (171/394) | STZ (Google: NYSE:STZ, Yahoo: STZ) | Constellation Brands Inc.
# Retreiving fundamental data from yfinance...
#
# (172/394) | GLW (Google: FRA:GLW, Yahoo: GLW.F) | Corning Inc.
# Retreiving fundamental data from yfinance...
#
# (173/394) | CMI (Google: NYSE:CMI, Yahoo: CMI) | Cummins Inc.
# Retreiving fundamental data from yfinance...
#
# (174/394) | DRI (Google: NYSE:DRI, Yahoo: DRI) | Darden Restaurants Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (175/394) | DE (Google: NYSE:DE, Yahoo: DE) | Deere & Company
# Retreiving fundamental data from yfinance...
#
# (176/394) | DAL (Google: NYSE:DAL, Yahoo: DAL) | Delta Air Lines Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (177/394) | DG (Google: NYSE:DG, Yahoo: DG) | Dollar General Corporation
# Retreiving fundamental data from yfinance...
#
# (178/394) | D (Google: NYSE:D, Yahoo: D) | Dominion Energy Inc.
# Retreiving fundamental data from yfinance...
#
# (179/394) | DOV (Google: FRA:DOV, Yahoo: DOV.F) | Dover Corporation
# Retreiving fundamental data from yfinance...
#
# (180/394) | DHI (Google: NYSE:DHI, Yahoo: DHI) | D.R. Horton Inc.
# Retreiving fundamental data from yfinance...
#
# (181/394) | DTE (Google: NYSE:DTE, Yahoo: DTE) | DTE Energy Company
# Retreiving fundamental data from yfinance...
#
# (182/394) | DXC (Google: NYSE:DXC, Yahoo: DXC) | DXC Technology Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (183/394) | EMN (Google: NYSE:EMN, Yahoo: EMN) | Eastman Chemical Company
# Retreiving fundamental data from yfinance...
#
# (184/394) | ETN (Google: NYSE:ETN, Yahoo: ETN) | Eaton Corporation PLC
# Retreiving fundamental data from yfinance...
#
# (185/394) | ECL (Google: NYSE:ECL, Yahoo: ECL) | Ecolab Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (186/394) | EIX (Google: FRA:EIX, Yahoo: EIX.F) | Edison International
# Retreiving fundamental data from yfinance...
#
# (187/394) | ETR (Google: NYSE:ETR, Yahoo: ETR) | Entergy Corporation
# Retreiving fundamental data from yfinance...
#
# (188/394) | EFX (Google: FRA:EFX, Yahoo: EFX.F) | Equifax Inc.
# Retreiving fundamental data from yfinance...
#
# (189/394) | EVRG (Google: NYSE:EVRG, Yahoo: EVRG) | Evergy Inc.
# Retreiving fundamental data from yfinance...
#
# (190/394) | ES (Google: NYSE:ES, Yahoo: ES) | Eversource Energy
# Retreiving fundamental data from yfinance...
#
# (191/394) | EXPD (Google: NASDAQ:EXPD, Yahoo: EXPD) | Expeditors International of Washington Inc.
# Retreiving fundamental data from yfinance...
#
# (192/394) | FFIV (Google: NASDAQ:FFIV, Yahoo: FFIV) | F5 Networks Inc.
# Retreiving fundamental data from yfinance...
#
# (193/394) | FE (Google: NYSE:FE, Yahoo: FE) | FirstEnergy Corp.
# Retreiving fundamental data from yfinance...
#
# (194/394) | FLT (Google: NYSE:FLT, Yahoo: FLT) | FleetCor Technologies Inc.
# Retreiving fundamental data from yfinance...
#
# (195/394) | FLIR (Google: NASDAQ:FLIR, Yahoo: FLIR) | FLIR Systems Inc.
# Retreiving fundamental data from yfinance...
# - FLIR: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (196/394) | FLS (Google: NYSE:FLS, Yahoo: FLS) | Flowserve Corporation
# Retreiving fundamental data from yfinance...
#
# (197/394) | FMC (Google: NYSE:FMC, Yahoo: FMC) | FMC Corporation
# Retreiving fundamental data from yfinance...
#
# (198/394) | FTNT (Google: NASDAQ:FTNT, Yahoo: FTNT) | Fortinet Inc.
# Retreiving fundamental data from yfinance...
#
# (199/394) | FTV (Google: NYSE:FTV, Yahoo: FTV) | Fortive Corporation
# Retreiving fundamental data from yfinance...
#
# (200/394) | FBHS (Google: NYSE:FBHS, Yahoo: FBHS) | Fortune Brands Home & Security Inc.
# Retreiving fundamental data from yfinance...
#
# (201/394) | GPS (Google: NYSE:GPS, Yahoo: GPS) | The Gap Inc.
# Retreiving fundamental data from yfinance...
#
# (202/394) | GRMN (Google: NASDAQ:GRMN, Yahoo: GRMN) | Garmin Ltd.
# Retreiving fundamental data from yfinance...
#
# (203/394) | IT (Google: NYSE:IT, Yahoo: IT) | Gartner Inc.
# Retreiving fundamental data from yfinance...
#
# (204/394) | GIS (Google: NYSE:GIS, Yahoo: GIS) | General Mills Inc.
# Retreiving fundamental data from yfinance...
#
# (205/394) | GPC (Google: NYSE:GPC, Yahoo: GPC) | Genuine Parts Company
# Retreiving fundamental data from yfinance...
#
# (206/394) | GPN (Google: NYSE:GPN, Yahoo: GPN) | Global Payments Inc.
# Retreiving fundamental data from yfinance...
#
# (207/394) | HBI (Google: NYSE:HBI, Yahoo: HBI) | Hanesbrands Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (208/394) | HAS (Google: FRA:HAS, Yahoo: HAS.F) | Hasbro Inc.
# Retreiving fundamental data from yfinance...
#
# (209/394) | HSY (Google: FRA:HSY, Yahoo: HSY.F) | The Hershey Company
# Retreiving fundamental data from yfinance...
#
# (210/394) | HPE (Google: NYSE:HPE, Yahoo: HPE) | Hewlett Packard Enterprise Company
# Retreiving fundamental data from yfinance...
#
# (211/394) | HLT (Google: NYSE:HLT, Yahoo: HLT) | Hilton Worldwide Holdings Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (212/394) | HRL (Google: NYSE:HRL, Yahoo: HRL) | Hormel Foods Corporation
# Retreiving fundamental data from yfinance...
#
# (213/394) | HPQ (Google: NYSE:HPQ, Yahoo: HPQ) | HP Inc.
# Retreiving fundamental data from yfinance...
#
# (214/394) | HII (Google: NYSE:HII, Yahoo: HII) | Huntington Ingalls Industries Inc.
# Retreiving fundamental data from yfinance...
#
# (215/394) | INFO (Google: NASDAQ:INFO, Yahoo: INFO) | IHS Markit Ltd.
# Retreiving fundamental data from yfinance...
#
# (216/394) | ITW (Google: NYSE:ITW, Yahoo: ITW) | Illinois Tool Works Inc.
# Retreiving fundamental data from yfinance...
#
# (217/394) | IR (Google: NYSE:IR, Yahoo: IR) | Ingersoll-Rand PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (218/394) | IPG (Google: FRA:IPG, Yahoo: IPG.F) | The Interpublic Group of Companies Inc.
# Retreiving fundamental data from yfinance...
#
# (219/394) | IPGP (Google: NASDAQ:IPGP, Yahoo: IPGP) | IPG Photonics Corporation
# Retreiving fundamental data from yfinance...
#
# (220/394) | JBHT (Google: NASDAQ:JBHT, Yahoo: JBHT) | J.B. Hunt Transport Services Inc.
# Retreiving fundamental data from yfinance...
#
# (221/394) | JKHY (Google: NASDAQ:JKHY, Yahoo: JKHY) | Jack Henry & Associates Inc.
# Retreiving fundamental data from yfinance...
#
# (222/394) | JEC (Google: NYSE:JEC, Yahoo: JEC) | Jacobs Engineering Group Inc.
# Retreiving fundamental data from yfinance...
# - JEC: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (223/394) | SJM (Google: NYSE:SJM, Yahoo: SJM) | The J. M. Smucker Company
# Retreiving fundamental data from yfinance...
#
# (224/394) | JCI (Google: NYSE:JCI, Yahoo: JCI) | Johnson Controls International PLC
# Retreiving fundamental data from yfinance...
#
# (225/394) | JNPR (Google: NYSE:JNPR, Yahoo: JNPR) | Juniper Networks Inc.
# Retreiving fundamental data from yfinance...
#
# (226/394) | KSU (Google: NYSE:KSU, Yahoo: KSU) | Kansas City Southern
# Retreiving fundamental data from yfinance...
#
# (227/394) | K (Google: NYSE:K, Yahoo: K) | Kellogg Company
# Retreiving fundamental data from yfinance...
#
# (228/394) | KEYS (Google: NYSE:KEYS, Yahoo: KEYS) | Keysight Technologies Inc.
# Retreiving fundamental data from yfinance...
#
# (229/394) | KMB (Google: NYSE:KMB, Yahoo: KMB) | Kimberly-Clark Corporation
# Retreiving fundamental data from yfinance...
#
# (230/394) | KR (Google: NYSE:KR, Yahoo: KR) | The Kroger Co.
# Retreiving fundamental data from yfinance...
#
# (231/394) | LB (Google: NYSE:LB, Yahoo: LB) | L Brands Inc.
# Retreiving fundamental data from yfinance...
# - LB: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (232/394) | LW (Google: NYSE:LW, Yahoo: LW) | Lamb Weston Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (233/394) | LEG (Google: NYSE:LEG, Yahoo: LEG) | Leggett & Platt Inc.
# Retreiving fundamental data from yfinance...
#
# (234/394) | LEN (Google: NYSE:LEN, Yahoo: LEN) | Lennar Corporation
# Retreiving fundamental data from yfinance...
#
# (235/394) | LKQ (Google: NASDAQ:LKQ, Yahoo: LKQ) | LKQ Corporation
# Retreiving fundamental data from yfinance...
#
# (236/394) | LYB (Google: NYSE:LYB, Yahoo: LYB) | LyondellBasell Industries N.V.
# Retreiving fundamental data from yfinance...
#
# (237/394) | MLM (Google: NYSE:MLM, Yahoo: MLM) | Martin Marietta Materials Inc.
# Retreiving fundamental data from yfinance...
#
# (238/394) | MAS (Google: NYSE:MAS, Yahoo: MAS) | Masco Corporation
# Retreiving fundamental data from yfinance...
#
# (239/394) | MKC (Google: NYSE:MKC, Yahoo: MKC) | McCormick & Company Inc.
# Retreiving fundamental data from yfinance...
#
# (240/394) | MCK (Google: FRA:MCK, Yahoo: MCK.F) | McKesson Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (241/394) | MTD (Google: NYSE:MTD, Yahoo: MTD) | Mettler-Toledo International Inc.
# Retreiving fundamental data from yfinance...
#
# (242/394) | MHK (Google: NYSE:MHK, Yahoo: MHK) | Mohawk Industries Inc.
# Retreiving fundamental data from yfinance...
#
# (243/394) | MOS (Google: NYSE:MOS, Yahoo: MOS) | The Mosaic Company
# Retreiving fundamental data from yfinance...
#
# (244/394) | MSI (Google: NYSE:MSI, Yahoo: MSI) | Motorola Solutions Inc.
# Retreiving fundamental data from yfinance...
#
# (245/394) | MSCI (Google: NYSE:MSCI, Yahoo: MSCI) | MSCI Inc.
# Retreiving fundamental data from yfinance...
#
# (246/394) | NWL (Google: FRA:NWL, Yahoo: NWL.F) | Newell Brands Inc.
# Retreiving fundamental data from yfinance...
#
# (247/394) | NWSA (Google: NASDAQ:NWSA, Yahoo: NWSA) | News Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (248/394) | NLSN (Google: NYSE:NLSN, Yahoo: NLSN) | Nielsen Holdings PLC
# Retreiving fundamental data from yfinance...
#
# (249/394) | NI (Google: NYSE:NI, Yahoo: NI) | NiSource Inc.
# Retreiving fundamental data from yfinance...
#
# (250/394) | NCLH (Google: NYSE:NCLH, Yahoo: NCLH) | Norwegian Cruise Line Holdings Ltd.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (251/394) | NRG (Google: NYSE:NRG, Yahoo: NRG) | NRG Energy Inc.
# Retreiving fundamental data from yfinance...
#
# (252/394) | OMC (Google: NYSE:OMC, Yahoo: OMC) | Omnicom Group Inc.
# Retreiving fundamental data from yfinance...
#
# (253/394) | PKG (Google: NYSE:PKG, Yahoo: PKG) | Packaging Corporation of America
# Retreiving fundamental data from yfinance...
#
# (254/394) | PH (Google: FRA:PH, Yahoo: PH.F) | Parker-Hannifin Corporation
# Retreiving fundamental data from yfinance...
# - PH.F: None
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (255/394) | PNR (Google: NYSE:PNR, Yahoo: PNR) | Pentair PLC
# Retreiving fundamental data from yfinance...
#
# (256/394) | PNW (Google: NYSE:PNW, Yahoo: PNW) | Pinnacle West Capital Corporation
# Retreiving fundamental data from yfinance...
#
# (257/394) | PPG (Google: NYSE:PPG, Yahoo: PPG) | PPG Industries Inc.
# Retreiving fundamental data from yfinance...
#
# (258/394) | PPL (Google: NYSE:PPL, Yahoo: PPL) | PPL Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (259/394) | PHM (Google: NYSE:PHM, Yahoo: PHM) | PulteGroup Inc.
# Retreiving fundamental data from yfinance...
#
# (260/394) | PVH (Google: FRA:PVH, Yahoo: PVH.F) | PVH Corp.
# Retreiving fundamental data from yfinance...
#
# (261/394) | QRVO (Google: NASDAQ:QRVO, Yahoo: QRVO) | Qorvo Inc.
# Retreiving fundamental data from yfinance...
#
# (262/394) | PWR (Google: NYSE:PWR, Yahoo: PWR) | Quanta Services Inc.
# Retreiving fundamental data from yfinance...
#
# (263/394) | RL (Google: NYSE:RL, Yahoo: RL) | Ralph Lauren Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (264/394) | RSG (Google: NYSE:RSG, Yahoo: RSG) | Republic Services Inc.
# Retreiving fundamental data from yfinance...
#
# (265/394) | RHI (Google: NYSE:RHI, Yahoo: RHI) | Robert Half International Inc.
# Retreiving fundamental data from yfinance...
#
# (266/394) | ROK (Google: NYSE:ROK, Yahoo: ROK) | Rockwell Automation Inc.
# Retreiving fundamental data from yfinance...
#
# (267/394) | ROL (Google: NYSE:ROL, Yahoo: ROL) | Rollins Inc.
# Retreiving fundamental data from yfinance...
#
# (268/394) | ROP (Google: FRA:ROP, Yahoo: ROP.F) | Roper Technologies Inc.
# Retreiving fundamental data from yfinance...
#
# (269/394) | RCL (Google: NYSE:RCL, Yahoo: RCL) | Royal Caribbean Cruises Ltd.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (270/394) | SPGI (Google: NYSE:SPGI, Yahoo: SPGI) | S&P Global Inc.
# Retreiving fundamental data from yfinance...
#
# (271/394) | SCHW (Google: NYSE:SCHW, Yahoo: SCHW) | The Charles Schwab Corporation
# Retreiving fundamental data from yfinance...
#
# (272/394) | SEE (Google: NYSE:SEE, Yahoo: SEE) | Sealed Air Corporation
# Retreiving fundamental data from yfinance...
#
# (273/394) | SRE (Google: NYSE:SRE, Yahoo: SRE) | Sempra Energy
# Retreiving fundamental data from yfinance...
#
# (274/394) | SHW (Google: NYSE:SHW, Yahoo: SHW) | The Sherwin-Williams Company
# Retreiving fundamental data from yfinance...
#
# (275/394) | SNA (Google: NYSE:SNA, Yahoo: SNA) | Snap-on Inc.
# Retreiving fundamental data from yfinance...
#
# (276/394) | LUV (Google: NYSE:LUV, Yahoo: LUV) | Southwest Airlines Co.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (277/394) | SWK (Google: NYSE:SWK, Yahoo: SWK) | Stanley Black & Decker Inc.
# Retreiving fundamental data from yfinance...
#
# (278/394) | SYY (Google: FRA:SYY, Yahoo: SYY.F) | Sysco Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (279/394) | TTWO (Google: NASDAQ:TTWO, Yahoo: TTWO) | Take-Two Interactive Software Inc.
# Retreiving fundamental data from yfinance...
#
# (280/394) | TPR (Google: NYSE:TPR, Yahoo: TPR) | Tapestry Inc.
# Retreiving fundamental data from yfinance...
#
# (281/394) | TEL (Google: NYSE:TEL, Yahoo: TEL) | TE Connectivity Ltd.
# Retreiving fundamental data from yfinance...
#
# (282/394) | TIF (Google: FRA:TIF, Yahoo: TIF.F) | Tiffany & Co.
# Retreiving fundamental data from yfinance...
# - TIF.F: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (283/394) | TJX (Google: FRA:TJX, Yahoo: TJX.F) | The TJX Companies Inc.
# Retreiving fundamental data from yfinance...
#
# (284/394) | TWTR (Google: NYSE:TWTR, Yahoo: TWTR) | Twitter Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (285/394) | TSN (Google: NYSE:TSN, Yahoo: TSN) | Tyson Foods Inc.
# Retreiving fundamental data from yfinance...
#
# (286/394) | UAA (Google: NYSE:UAA, Yahoo: UAA) | Under Armour Inc.
# Retreiving fundamental data from yfinance...
#
# (287/394) | UAL (Google: NASDAQ:UAL, Yahoo: UAL) | United Continental Holdings Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (288/394) | URI (Google: NYSE:URI, Yahoo: URI) | United Rentals Inc.
# Retreiving fundamental data from yfinance...
#
# (289/394) | VFC (Google: NYSE:VFC, Yahoo: VFC) | V.F. Corporation
# Retreiving fundamental data from yfinance...
#
# (290/394) | VMC (Google: FRA:VMC, Yahoo: VMC.F) | Vulcan Materials Company
# Retreiving fundamental data from yfinance...
#
# (291/394) | WAB (Google: NYSE:WAB, Yahoo: WAB) | Wabtec Corporation
# Retreiving fundamental data from yfinance...
#
# (292/394) | WM (Google: NYSE:WM, Yahoo: WM) | Waste Management Inc.
# Retreiving fundamental data from yfinance...
#
# (293/394) | WEC (Google: NYSE:WEC, Yahoo: WEC) | WEC Energy Group Inc.
# Retreiving fundamental data from yfinance...
#
# (294/394) | WU (Google: NYSE:WU, Yahoo: WU) | The Western Union Company
# Retreiving fundamental data from yfinance...
#
# (295/394) | WRK (Google: FRA:WRK, Yahoo: WRK.F) | WestRock Company
# Retreiving fundamental data from yfinance...
# - WRK.F: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (296/394) | WHR (Google: FRA:WHR, Yahoo: WHR.F) | Whirlpool Corporation
# Retreiving fundamental data from yfinance...
#
# (297/394) | XRX (Google: NYSE:XRX, Yahoo: XRX) | Xerox Corporation
# Retreiving fundamental data from yfinance...
#
# (298/394) | XYL (Google: NYSE:XYL, Yahoo: XYL) | Xylem Inc.
# Retreiving fundamental data from yfinance...
#
# (299/394) | YUM (Google: NYSE:YUM, Yahoo: YUM) | YUM! Brands Inc.
# Retreiving fundamental data from yfinance...
#
# (300/394) | CTVA (Google: NYSE:CTVA, Yahoo: CTVA) | Corteva Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (301/394) | LNT (Google: NASDAQ:LNT, Yahoo: LNT) | Alliant Energy Corporation
# Retreiving fundamental data from yfinance...
#
# (302/394) | AMCR (Google: NYSE:AMCR, Yahoo: AMCR) | Amcor plc
# Retreiving fundamental data from yfinance...
#
# (303/394) | BKR (Google: NYSE:BKR, Yahoo: BKR) | Baker Hughes Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (304/394) | BIO (Google: NYSE:BIO, Yahoo: BIO) | Bio-Rad Laboratories, Inc.
# Retreiving fundamental data from yfinance...
#
# (305/394) | CARR (Google: NYSE:CARR, Yahoo: CARR) | Carrier Global Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (306/394) | CTLT (Google: NYSE:CTLT, Yahoo: CTLT) | Catalent, Inc.
# Retreiving fundamental data from yfinance...
#
# (307/394) | DPZ (Google: NYSE:DPZ, Yahoo: DPZ) | Domino's Pizza, Inc.
# Retreiving fundamental data from yfinance...
#
# (308/394) | ETSY (Google: NASDAQ:ETSY, Yahoo: ETSY) | Etsy, Inc.
# Retreiving fundamental data from yfinance...
#
# (309/394) | HWM (Google: NYSE:HWM, Yahoo: HWM) | Howmet Aerospace Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (310/394) | IEX (Google: NYSE:IEX, Yahoo: IEX) | IDEX Corporation
# Retreiving fundamental data from yfinance...
#
# (311/394) | LVS (Google: NYSE:LVS, Yahoo: LVS) | Las Vegas Sands Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (312/394) | LYV (Google: NYSE:LYV, Yahoo: LYV) | Live Nation Entertainment, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (313/394) | LUMN (Google: NYSE:LUMN, Yahoo: LUMN) | Lumen Technologies, Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (314/394) | MKTX (Google: NASDAQ:MKTX, Yahoo: MKTX) | MarketAxess Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (315/394) | TAP (Google: NYSE:TAP, Yahoo: TAP) | Molson Coors Beverage Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (316/394) | NOC (Google: NYSE:NOC, Yahoo: NOC) | Northrop Grumman Corporation
# Retreiving fundamental data from yfinance...
#
# (317/394) | NLOK (Google: NASDAQ:NLOK, Yahoo: NLOK) | NortonLifeLock Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (318/394) | NVR (Google: NYSE:NVR, Yahoo: NVR) | NVR, Inc.
# Retreiving fundamental data from yfinance...
#
# (319/394) | ODFL (Google: NASDAQ:ODFL, Yahoo: ODFL) | Old Dominion Freight Line, Inc.
# Retreiving fundamental data from yfinance...
#
# (320/394) | OTIS (Google: NYSE:OTIS, Yahoo: OTIS) | Otis Worldwide Corporation
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (321/394) | PAYC (Google: NYSE:PAYC, Yahoo: PAYC) | Paycom Software, Inc.
# Retreiving fundamental data from yfinance...
#
# (322/394) | POOL (Google: NASDAQ:POOL, Yahoo: POOL) | Pool Corporation
# Retreiving fundamental data from yfinance...
#
# (323/394) | PFG (Google: NASDAQ:PFG, Yahoo: PFG) | Principal Financial Group, Inc.
# Retreiving fundamental data from yfinance...
#
# (324/394) | NOW (Google: NYSE:NOW, Yahoo: NOW) | ServiceNow, Inc.
# Retreiving fundamental data from yfinance...
#
# (325/394) | TDY (Google: NYSE:TDY, Yahoo: TDY) | Teledyne Technologies Incorporated
# Retreiving fundamental data from yfinance...
#
# (326/394) | TER (Google: NASDAQ:TER, Yahoo: TER) | Teradyne, Inc.
# Retreiving fundamental data from yfinance...
#
# (327/394) | TXT (Google: NYSE:TXT, Yahoo: TXT) | Textron Inc.
# Retreiving fundamental data from yfinance...
#
# (328/394) | TT (Google: NYSE:TT, Yahoo: TT) | Trane Technologies plc
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (329/394) | TYL (Google: NYSE:TYL, Yahoo: TYL) | Tyler Technologies, Inc.
# Retreiving fundamental data from yfinance...
#
# (330/394) | VIAC (Google: NASDAQ:VIAC, Yahoo: VIAC) | ViacomCBS Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (331/394) | VTRS (Google: NASDAQ:VTRS, Yahoo: VTRS) | Viatris Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (332/394) | WST (Google: NYSE:WST, Yahoo: WST) | West Pharmaceutical Services, Inc.
# Retreiving fundamental data from yfinance...
#
# (333/394) | ZBRA (Google: NASDAQ:ZBRA, Yahoo: ZBRA) | Zebra Technologies Corporation
# Retreiving fundamental data from yfinance...
#
# (334/394) | AHT (Google: FRA:AHT, Yahoo: AHT.F) | Ashtead Group PLC
# Retreiving fundamental data from yfinance...
#
# (335/394) | ABF (Google: FRA:ABF, Yahoo: ABF.F) | Associated British Foods PLC
# Retreiving fundamental data from yfinance...
# - ABF.F: None
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (336/394) | AUTO (Google: FRA:AUTO, Yahoo: AUTO.F) | Auto Trader Group PLC
# Retreiving fundamental data from yfinance...
# - AUTO.F: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (337/394) | BDEV (Google: FRA:BDEV, Yahoo: BDEV.F) | Barratt Developments PLC
# Retreiving fundamental data from yfinance...
# - BDEV.F: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (338/394) | BKG (Google: FRA:BKG, Yahoo: BKG.F) | Berkeley Group Holdings/The
# Retreiving fundamental data from yfinance...
#
# (339/394) | BATS (Google: FRA:BATS, Yahoo: BATS.F) | British American Tobacco p.l.c.
# Retreiving fundamental data from yfinance...
# - BATS.F: No data found, symbol may be delisted
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (340/394) | BNZL (Google: LON:BNZL, Yahoo: BNZL.L) | Bunzl PLC
# Retreiving fundamental data from yfinance...
#
# (341/394) | BRBY (Google: LON:BRBY, Yahoo: BRBY.L) | Burberry Group PLC
# Retreiving fundamental data from yfinance...
#
# (342/394) | CCH (Google: LON:CCH, Yahoo: CCH.L) | Coca-Cola HBC AG
# Retreiving fundamental data from yfinance...
#
# (343/394) | CPG (Google: LON:CPG, Yahoo: CPG.L) | Compass Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (344/394) | CRH (Google: NYSE:CRH, Yahoo: CRH) | CRH PLC
# Retreiving fundamental data from yfinance...
#
# (345/394) | CRDA (Google: LON:CRDA, Yahoo: CRDA.L) | Croda International PLC
# Retreiving fundamental data from yfinance...
#
# (346/394) | DGE (Google: LON:DGE, Yahoo: DGE.L) | Diageo PLC
# Retreiving fundamental data from yfinance...
#
# (347/394) | SMDS (Google: LON:SMDS, Yahoo: SMDS.L) | DS Smith PLC
# Retreiving fundamental data from yfinance...
#
# (348/394) | EXPN (Google: LON:EXPN, Yahoo: EXPN.L) | Experian PLC
# Retreiving fundamental data from yfinance...
#
# (349/394) | HLMA (Google: LON:HLMA, Yahoo: HLMA.L) | Halma PLC
# Retreiving fundamental data from yfinance...
#
# (350/394) | IMB (Google: LON:IMB, Yahoo: IMB.L) | Imperial Brands PLC
# Retreiving fundamental data from yfinance...
#
# (351/394) | INF (Google: LON:INF, Yahoo: INF.L) | Informa PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (352/394) | IHG (Google: LON:IHG, Yahoo: IHG.L) | InterContinental Hotels Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (353/394) | IAG (Google: BME:IAG, Yahoo: IAG.MC) | International Consolidated Airlines Group SA
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (354/394) | ITRK (Google: LON:ITRK, Yahoo: ITRK.L) | Intertek Group PLC
# Retreiving fundamental data from yfinance...
#
# (355/394) | JMAT (Google: LON:JMAT, Yahoo: JMAT.L) | Johnson Matthey PLC
# Retreiving fundamental data from yfinance...
#
# (356/394) | KGF (Google: LON:KGF, Yahoo: KGF.L) | Kingfisher PLC
# Retreiving fundamental data from yfinance...
#
# (357/394) | MRO (Google: LON:MRO, Yahoo: MRO.L) | Melrose Industries PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (358/394) | NXT (Google: LON:NXT, Yahoo: NXT.L) | NEXT PLC
# Retreiving fundamental data from yfinance...
#
# (359/394) | OCDO (Google: LON:OCDO, Yahoo: OCDO.L) | Ocado Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (360/394) | PSON (Google: LON:PSON, Yahoo: PSON.L) | Pearson PLC
# Retreiving fundamental data from yfinance...
#
# (361/394) | PSN (Google: LON:PSN, Yahoo: PSN.L) | Persimmon PLC
# Retreiving fundamental data from yfinance...
#
# (362/394) | REL (Google: LON:REL, Yahoo: REL.L) | RELX PLC
# Retreiving fundamental data from yfinance...
#
# (363/394) | RTO (Google: FRA:RTO, Yahoo: RTO.F) | Rentokil Initial PLC
# Retreiving fundamental data from yfinance...
#
# (364/394) | RMV (Google: LON:RMV, Yahoo: RMV.L) | Rightmove PLC
# Retreiving fundamental data from yfinance...
#
# (365/394) | SGE (Google: LON:SGE, Yahoo: SGE.L) | The Sage Group PLC
# Retreiving fundamental data from yfinance...
#
# (366/394) | SBRY (Google: LON:SBRY, Yahoo: SBRY.L) | J Sainsbury PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (367/394) | SMT (Google: LON:SMT, Yahoo: SMT.L) | Scottish Mortgage Investment Trust PLC
# Retreiving fundamental data from yfinance...
#
# (368/394) | SVT (Google: LON:SVT, Yahoo: SVT.L) | Severn Trent PLC
# Retreiving fundamental data from yfinance...
#
# (369/394) | SMIN (Google: LON:SMIN, Yahoo: SMIN.L) | Smiths Group PLC
# Retreiving fundamental data from yfinance...
#
# (370/394) | SKG (Google: LON:SKG, Yahoo: SKG.L) | Smurfit Kappa Group PLC
# Retreiving fundamental data from yfinance...
#
# (371/394) | SPX (Google: LON:SPX, Yahoo: SPX.L) | Spirax-Sarco Engineering PLC
# Retreiving fundamental data from yfinance...
#
# (372/394) | ULVR (Google: LON:ULVR, Yahoo: ULVR.L) | Unilever PLC
# Retreiving fundamental data from yfinance...
#
# (373/394) | VOD (Google: NASDAQ:VOD, Yahoo: VOD) | Vodafone Group PLC
# Retreiving fundamental data from yfinance...
#
# (374/394) | WTB (Google: LON:WTB, Yahoo: WTB.L) | Whitbread PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (375/394) | MRW (Google: LON:MRW, Yahoo: MRW.L) | Wm Morrison Supermarkets PLC
# Retreiving fundamental data from yfinance...
#
# (376/394) | WPP (Google: LON:WPP, Yahoo: WPP.L) | WPP PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (377/394) | FERG (Google: LON:FERG, Yahoo: FERG.L) | Ferguson PLC
# Retreiving fundamental data from yfinance...
#
# (378/394) | AVV (Google: LON:AVV, Yahoo: AVV.L) | AVEVA Group plc
# Retreiving fundamental data from yfinance...
#
# (379/394) | PNN (Google: LON:PNN, Yahoo: PNN.L) | Pennon Group plc
# Retreiving fundamental data from yfinance...
#
# (380/394) | SSE (Google: LON:SSE, Yahoo: SSE.L) | SSE plc
# Retreiving fundamental data from yfinance...
#
# (381/394) | ADS (Google: FRA:ADS, Yahoo: ADS.F) | adidas AG
# Retreiving fundamental data from yfinance...
#
# (382/394) | BAS (Google: FRA:BAS, Yahoo: BAS.F) | BASF SE
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (383/394) | BMW (Google: FRA:BMW, Yahoo: BMW.F) | Bayerische Motoren Werke AG
# Retreiving fundamental data from yfinance...
#
# (384/394) | DAI (Google: FRA:DAI, Yahoo: DAI.F) | Daimler AG
# Retreiving fundamental data from yfinance...
#
# (385/394) | DPW (Google: FRA:DPW, Yahoo: DPW.F) | Deutsche Post AG
# Retreiving fundamental data from yfinance...
#
# (386/394) | EOAN (Google: FRA:EOAN, Yahoo: EOAN.F) | E.ON SE
# Retreiving fundamental data from yfinance...
#
# (387/394) | SAP (Google: FRA:SAP, Yahoo: SAP.F) | SAP SE
# Retreiving fundamental data from yfinance...
#
# (388/394) | SIE (Google: FRA:SIE, Yahoo: SIE.F) | Siemens AG
# Retreiving fundamental data from yfinance...
#
# (389/394) | VOW3 (Google: FRA:VOW3, Yahoo: VOW3.F) | Volkswagen AG
# Retreiving fundamental data from yfinance...
#
# (390/394) | AIR (Google: FRA:AIR, Yahoo: AIR.F) | Airbus SE
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (391/394) | AMS (Google: BME:AMS, Yahoo: AMS.MC) | Amadeus IT Group SA
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (392/394) | IBE (Google: BME:IBE, Yahoo: IBE.MC) | Iberdrola SA
# Retreiving fundamental data from yfinance...
#
# (393/394) | AD (Google: AMS:AD, Yahoo: AD.AS) | Koninklijke Ahold Delhaize N.V.
# Retreiving fundamental data from yfinance...
#
# (394/394) | ENI (Google: FRA:ENI, Yahoo: ENI.F) | Eni S.p.A.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!

# %%
# Calculating percentiles
print('Calculating percentiles...')

metrics_long = {
    'PriceToEarningsRatio': 'PriceToEarningsPercentile',
    'PriceToSalesRatio': 'PriceToSalesInversePercentile',
    'EV_EBITDA':'EV_EBITDAPercentile',
    'EV_R':'EV_RInversePercentile'
}

metrics_short = {
    'PriceToEarningsRatio': 'PriceToEarningsInversePercentile',
    'PriceToSalesRatio': 'PriceToSalesPercentile',
    'EV_R':'EV_RPercentile'
}

for row in so_dataframe.index:
    for metric in metrics_long.keys():
        if(metric == 'PriceToSalesRatio' or metric == 'EV_R'):
            so_dataframe.loc[row, metrics_long[metric]] = stats.percentileofscore(1 / so_dataframe[metric], 1 / so_dataframe.loc[row, metric])
        else:
            so_dataframe.loc[row, metrics_long[metric]] = stats.percentileofscore(so_dataframe[metric], so_dataframe.loc[row, metric])

    for metric in metrics_short.keys():
        if(metric == 'PriceToEarningsRatio'):
            so_dataframe.loc[row, metrics_short[metric]] = stats.percentileofscore(1 / so_dataframe[metric], 1 / so_dataframe.loc[row, metric])
        else:
            so_dataframe.loc[row, metrics_short[metric]] = stats.percentileofscore(so_dataframe[metric], so_dataframe.loc[row, metric])
            

# Scoring stocks
print('Scoring stocks...')
for row in so_dataframe.index:
    value_percentiles = []
    for metric in metrics_long.keys():
        value_percentiles.append(so_dataframe.loc[row, metrics_long[metric]])
    so_dataframe.loc[row, 'Score_Long'] = mean(value_percentiles)

    value_percentiles = []
    for metric in metrics_short.keys():
        value_percentiles.append(so_dataframe.loc[row, metrics_short[metric]])
    so_dataframe.loc[row, 'Score_Short'] = mean(value_percentiles)

# Sorting and selecting
result_df = so_dataframe.copy()
result_df.sort_values(by = 'Company', inplace = True, ascending=True)
result_df['MarketCap_USD'] = result_df['MarketCap'] * result_df['Currency'].apply(sou.get_usd_rate)
result_df = result_df[['Company','Symbol','Symbol_Google','Symbol_Yahoo','Description','Country','Indices','Industries','Currency','MarketCap','MarketCap_USD','Y1HighestPriceValue','Y1HighestPriceDate', 'PriceToEarningsRatio','PriceToEarningsPercentile','PriceToEarningsInversePercentile','PriceToSalesRatio','PriceToSalesPercentile','PriceToSalesInversePercentile','EV_EBITDA','EV_EBITDAPercentile','EV_R','EV_RPercentile','EV_RInversePercentile','Score_Long','Score_Short']]
skipped_count = initial_count - len(result_df)
now = DateTime.now()

print()
print(f'Scoring executed successfully at {now.hour}:{now.minute} | {total_stocks} listed | {errors} not found | {skipped_count} skipped | {len(result_df)} scored stocks')

with open("md.txt", "a", encoding='utf-8') as f:
    md_df = result_df[['Company','Symbol','Symbol_Google','Symbol_Yahoo','Currency','MarketCap','MarketCap_USD','PriceToEarningsRatio','PriceToEarningsPercentile','PriceToEarningsInversePercentile','PriceToSalesRatio','PriceToSalesPercentile','PriceToSalesInversePercentile','EV_EBITDA','EV_EBITDAPercentile','EV_R','EV_RPercentile','EV_RInversePercentile','Score_Long','Score_Short']]
    md_df.columns = ['Company','Symbol','Google Symbol','Yahoo Symbol', 'Currency','Market Cap', 'Market Cap (USD)','P/E', 'P/E PC', 'P/E INV-PC','P/S','P/S PC','P/S INV-PC','EV/EBITDA','EV/EBITDA PC','EV/R','EV/R PC','EV/R INV-PC','Score for Long','Score for Short']
    f.write(md_df.to_markdown(index=False))
# Out:
# Calculating percentiles...
# Scoring stocks...
#
# Scoring executed successfully at 19:24 | 394 listed | 75 not found | 14 skipped | 305 scored stocks

# %%
writer = pd.ExcelWriter('market_stock_value_scoring.xlsx', engine='xlsxwriter')
result_df.to_excel(writer, sheet_name='Value Scoring', index = False)

# Defining Excel columns formats and templates
background_light_color = '#ffffff'
background_dark_color = '#eeeeee'
background_accent_color = '#0086CD'
black_color = '#000000'
white_color = '#ffffff'

string_template = writer.book.add_format(
        {
            'font_color': black_color,
            'bg_color': background_light_color,
            'border': 0
        }
    )

float_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': black_color,
            'bg_color': background_light_color,
            'border': 0
        }
    )

percentile_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': black_color,
            'bg_color': background_dark_color,
            'border': 0
        }
    )

score_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': white_color,
            'bg_color': background_accent_color,
            'border': 0
        }
    )

print('Saving scoring in Excel...\n')

column_formats = {
    'A': ['Company', string_template],
    'B': ['Symbol', string_template],
    'C': ['Symbol_Google', string_template],
    'D': ['Symbol_Yahoo', string_template],
    'E': ['Description', string_template],
    'F': ['Country', string_template],
    'G': ['Indices', string_template],
    'H': ['Industries', string_template],
    'I': ['Currency', string_template],
    'J': ['MarketCap', float_template],
    'K': ['MarketCap_USD', float_template],
    'L': ['Y1HighestPriceValue', float_template],
    'M': ['Y1HighestPriceDate', string_template],
    'N': ['PriceToEarningsRatio', float_template],
    'O': ['PriceToEarningsPercentile', percentile_template],
    'P': ['PriceToEarningsInversePercentile', percentile_template],
    'Q': ['PriceToSalesRatio', float_template],
    'R': ['PriceToSalesPercentile', percentile_template],
    'S': ['PriceToSalesInversePercentile', percentile_template],
    'T': ['EV_EBITDA', float_template],
    'U': ['EV_EBITDAPercentile', percentile_template],
    'V': ['EV_R', float_template],
    'W': ['EV_RPercentile', percentile_template],
    'X': ['EV_RInversePercentile', percentile_template],
    'Y': ['Score_Long', score_template],
    'Z': ['Score_Short', score_template]
}

for column in column_formats.keys():
    writer.sheets['Value Scoring'].set_column(f'{column}:{column}', 25, column_formats[column][1])
    writer.sheets['Value Scoring'].write(f'{column}1', column_formats[column][0], column_formats[column][1])

writer.save()
# Out:
# Saving scoring in Excel...
