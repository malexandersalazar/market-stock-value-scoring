# %%
import pandas as pd
from scipy import stats
from statistics import mean
from datetime import datetime as DateTime
import yfinance as yf
import pytickersymbols as pts

# %%
yf.__version__
# Out:
# '0.1.62'

# %%
pts.__version__
# Out:
# '1.4.3'

# %% [markdown]
# ## Acquiring information about stocks

# %%
stock_data = pts.PyTickerSymbols()

eu50_stocks = stock_data.get_stocks_by_index('EURO STOXX 50')
us30_stocks = stock_data.get_stocks_by_index('DOW JONES')
uk100_stocks = stock_data.get_stocks_by_index('FTSE 100')
us100_stocks = stock_data.get_stocks_by_index('S&P 100')

market_stocks = list(eu50_stocks) + list(us30_stocks) + list(uk100_stocks) + list(us100_stocks)

excluded_sectors = ['Biotechnology & Medical Research','Online gambling','Pharmaceuticals','Healthcare','Managed Health care','Medical Equipment','Banking & Investment Services','Medical Equipment, Supplies & Distribution','Metals & Mining','Metal','Insurance','Commercial REITs','Specialized REITs','Financial services','Beverages','Food & Beverages','Real Estate','Casinos & Gaming','Fossil Fuels']

stocks_list = []
for market_stock in market_stocks:
    try:
        ignore = False
        for market_industry in market_stock['industries']:
            if(market_industry in excluded_sectors):
                ignore = True
                break
            
        if(ignore):
            continue

        stock_symbol = market_stock['symbol']
        symbols = market_stock['symbols']

        symbol_google = None
        symbol_yahoo = None
        for symbol in symbols:
            if(symbol['google'].endswith(f':{stock_symbol}')):
                symbol_google = symbol['google']
                symbol_yahoo = symbol['yahoo']
                break

        if(symbol_yahoo is None):
            continue

        item = {
            'Company': market_stock['name'],
            'Symbol': stock_symbol,
            'Symbol_Google': symbol_google,
            'Symbol_Yahoo': symbol_yahoo,
            'Country': market_stock['country'],
            'Indices': ', '.join(market_stock['indices']),
            'Sectors': ', '.join(market_stock['industries'])
        }

        stocks_list.append(item)
    except:
        pass

stocks = pd.DataFrame(stocks_list, columns=['Company','Symbol','Symbol_Google','Symbol_Yahoo','Country','Indices','Sectors'])
stocks
# Out:
#                           Company Symbol Symbol_Google Symbol_Yahoo  \
# 0                       adidas AG    ADS       FRA:ADS        ADS.F
# 1                         BASF SE    BAS       FRA:BAS        BAS.F
# 2     Bayerische Motoren Werke AG    BMW       FRA:BMW        BMW.F
# 3                      Daimler AG    DAI       FRA:DAI        DAI.F
# 4                Deutsche Post AG    DPW       FRA:DPW        DPW.F
# ..                            ...    ...           ...          ...
# 133    United Parcel Service Inc.    UPS      NYSE:UPS          UPS
# 134           salesforce.com Inc.    CRM      NYSE:CRM          CRM
# 135                      Dow Inc.    DOW      NYSE:DOW          DOW
# 136  General Dynamics Corporation     GD       NYSE:GD           GD
# 137   Lockheed Martin Corporation    LMT      NYSE:LMT          LMT
#
#            Country                      Indices  \
# 0          Germany           DAX, EURO STOXX 50
# 1          Germany           DAX, EURO STOXX 50
# 2          Germany           DAX, EURO STOXX 50
# 3          Germany           DAX, EURO STOXX 50
# 4          Germany           DAX, EURO STOXX 50
# ..             ...                          ...
# 133  United States             S&P 100, S&P 500
# 134  United States  DOW JONES, S&P 100, S&P 500
# 135  United States  DOW JONES, S&P 100, S&P 500
# 136  United States             S&P 100, S&P 500
# 137  United States             S&P 100, S&P 500
#
#                                                Sectors
# 0    Cyclical Consumer Products, Footwear, Textiles...
# 1    Diversified Chemicals, Basic Materials, Chemicals
# 2    Automotive, Auto & Truck Manufacturers, Automo...
# 3    Automotive, Auto & Truck Manufacturers, Automo...
# 4    Industrials, Air Freight & Courier Services, F...
# ..                                                 ...
# 133  Industrial Goods, Industrials, Aerospace & Def...
# 134  Technology, Software & IT Services, IT Service...
# 135                                          Chemicals
# 136                                 Aerospace, Defense
# 137          Advanced Technologies, Aerospace, Defense
#
# [138 rows x 7 columns]

# %%
# Some stocks are listed on more than the stock index.
stocks.set_index('Symbol',inplace=True)
stocks = stocks[~stocks.index.duplicated(keep='first')]
stocks
# Out:
#                              Company Symbol_Google Symbol_Yahoo  \
# Symbol
# ADS                        adidas AG       FRA:ADS        ADS.F
# BAS                          BASF SE       FRA:BAS        BAS.F
# BMW      Bayerische Motoren Werke AG       FRA:BMW        BMW.F
# DAI                       Daimler AG       FRA:DAI        DAI.F
# DPW                 Deutsche Post AG       FRA:DPW        DPW.F
# ...                              ...           ...          ...
# TGT               Target Corporation      NYSE:TGT          TGT
# UNP        Union Pacific Corporation       FRA:UNP        UNP.F
# UPS       United Parcel Service Inc.      NYSE:UPS          UPS
# GD      General Dynamics Corporation       NYSE:GD           GD
# LMT      Lockheed Martin Corporation      NYSE:LMT          LMT
#
#               Country             Indices  \
# Symbol
# ADS           Germany  DAX, EURO STOXX 50
# BAS           Germany  DAX, EURO STOXX 50
# BMW           Germany  DAX, EURO STOXX 50
# DAI           Germany  DAX, EURO STOXX 50
# DPW           Germany  DAX, EURO STOXX 50
# ...               ...                 ...
# TGT     United States    S&P 100, S&P 500
# UNP     United States    S&P 100, S&P 500
# UPS     United States    S&P 100, S&P 500
# GD      United States    S&P 100, S&P 500
# LMT     United States    S&P 100, S&P 500
#
#                                                   Sectors
# Symbol
# ADS     Cyclical Consumer Products, Footwear, Textiles...
# BAS     Diversified Chemicals, Basic Materials, Chemicals
# BMW     Automotive, Auto & Truck Manufacturers, Automo...
# DAI     Automotive, Auto & Truck Manufacturers, Automo...
# DPW     Industrials, Air Freight & Courier Services, F...
# ...                                                   ...
# TGT     Diversified Retail, Retailers, Discount Stores...
# UNP     Ground Freight & Logistics, Industrials, Freig...
# UPS     Industrial Goods, Industrials, Aerospace & Def...
# GD                                     Aerospace, Defense
# LMT             Advanced Technologies, Aerospace, Defense
#
# [116 rows x 6 columns]

# %% [markdown]
# ## Transforming data for value calculation

# %%
# Defining stocks value scoring dataframe

df_columns = [
    'Company',
    'Symbol',
    'Symbol_Google',
    'Symbol_Yahoo',
    'Description',
    'Country',        
    'Indices',
    'Sectors',
    'Price',
    'PriceToEarningsRatio',
    'PriceToEarningsPercentile',
    'PriceToSalesRatio',
    'PriceToSalesPercentile',
    'EV_EBITDA',
    'EV_EBITDAPercentile',
    'EV_R',
    'EV_RPercentile',
    'Score'
]

so_dataframe = pd.DataFrame(columns = df_columns)

# Getting fundamental data
i = 0
total_stocks = len(stocks)
errors = 0
for index, stock in stocks.iterrows():
    i+=1
    stock_name = stock['Company']
    symbol = index

    symbol_google = stock['Symbol_Google']
    symbol_yahoo = stock['Symbol_Yahoo']

    print(f'({i}/{total_stocks}) | {symbol} (Google: {symbol_google}, Yahoo: {symbol_yahoo}) | {stock_name}')
    print(f'Retreiving fundamental data from yfinance...')

    try:
        yf_ticker = yf.Ticker(symbol_yahoo)
        so_dataframe = so_dataframe.append(
            pd.Series([
                stock_name,
                symbol,
                symbol_google,
                symbol_yahoo,
                yf_ticker.info['longBusinessSummary'],
                stock['Country'],
                stock['Indices'],
                stock['Sectors'],
                yf_ticker.info['regularMarketPrice'],
                yf_ticker.info['trailingPE'],
                'N/A',
                yf_ticker.info['priceToSalesTrailing12Months'],
                'N/A',
                yf_ticker.info['enterpriseToEbitda'],
                'N/A',
                yf_ticker.info['enterpriseToRevenue'],
                'N/A',
                'N/A'
            ], index = df_columns),
            ignore_index = True)

    except Exception as error:
        print('ERROR:', error)
        errors+=1
        print('An error occurred while trying to get the information!')
        
    print()

initial_count = len(so_dataframe)

# Dealing With Missing Data
so_dataframe = so_dataframe.dropna()
# Out:
# (1/116) | ADS (Google: FRA:ADS, Yahoo: ADS.F) | adidas AG
# Retreiving fundamental data from yfinance...
#
# (2/116) | BAS (Google: FRA:BAS, Yahoo: BAS.F) | BASF SE
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (3/116) | BMW (Google: FRA:BMW, Yahoo: BMW.F) | Bayerische Motoren Werke AG
# Retreiving fundamental data from yfinance...
#
# (4/116) | DAI (Google: FRA:DAI, Yahoo: DAI.F) | Daimler AG
# Retreiving fundamental data from yfinance...
#
# (5/116) | DPW (Google: FRA:DPW, Yahoo: DPW.F) | Deutsche Post AG
# Retreiving fundamental data from yfinance...
#
# (6/116) | DTE (Google: FRA:DTE, Yahoo: DTE.F) | Deutsche Telekom AG
# Retreiving fundamental data from yfinance...
#
# (7/116) | EOAN (Google: FRA:EOAN, Yahoo: EOAN.F) | E.ON SE
# Retreiving fundamental data from yfinance...
#
# (8/116) | LIN (Google: FRA:LIN, Yahoo: LIN.F) | Linde PLC
# Retreiving fundamental data from yfinance...
#
# (9/116) | SAP (Google: FRA:SAP, Yahoo: SAP.F) | SAP SE
# Retreiving fundamental data from yfinance...
#
# (10/116) | SIE (Google: FRA:SIE, Yahoo: SIE.F) | Siemens AG
# Retreiving fundamental data from yfinance...
#
# (11/116) | VOW3 (Google: FRA:VOW3, Yahoo: VOW3.F) | Volkswagen AG
# Retreiving fundamental data from yfinance...
#
# (12/116) | AIR (Google: FRA:AIR, Yahoo: AIR.F) | Airbus SE
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (13/116) | CRH (Google: NYSE:CRH, Yahoo: CRH) | CRH PLC
# Retreiving fundamental data from yfinance...
#
# (14/116) | ULVR (Google: LON:ULVR, Yahoo: ULVR.L) | Unilever PLC
# Retreiving fundamental data from yfinance...
#
# (15/116) | AMS (Google: BME:AMS, Yahoo: AMS.MC) | Amadeus IT Group SA
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (16/116) | IBE (Google: BME:IBE, Yahoo: IBE.MC) | Iberdrola SA
# Retreiving fundamental data from yfinance...
#
# (17/116) | AD (Google: AMS:AD, Yahoo: AD.AS) | Koninklijke Ahold Delhaize N.V.
# Retreiving fundamental data from yfinance...
#
# (18/116) | ASML (Google: NASDAQ:ASML, Yahoo: ASML) | ASML Holding N.V.
# Retreiving fundamental data from yfinance...
#
# (19/116) | ENI (Google: FRA:ENI, Yahoo: ENI.F) | Eni S.p.A.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (20/116) | MMM (Google: FRA:MMM, Yahoo: MMM.F) | 3M Company
# Retreiving fundamental data from yfinance...
#
# (21/116) | AAPL (Google: NASDAQ:AAPL, Yahoo: AAPL) | Apple Inc.
# Retreiving fundamental data from yfinance...
#
# (22/116) | BA (Google: NYSE:BA, Yahoo: BA) | The Boeing Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (23/116) | CAT (Google: NYSE:CAT, Yahoo: CAT) | Caterpillar Inc.
# Retreiving fundamental data from yfinance...
#
# (24/116) | CSCO (Google: NASDAQ:CSCO, Yahoo: CSCO) | Cisco Systems Inc.
# Retreiving fundamental data from yfinance...
#
# (25/116) | HD (Google: NYSE:HD, Yahoo: HD) | The Home Depot Inc.
# Retreiving fundamental data from yfinance...
#
# (26/116) | IBM (Google: FRA:IBM, Yahoo: IBM.F) | International Business Machines Corporation
# Retreiving fundamental data from yfinance...
#
# (27/116) | INTC (Google: NASDAQ:INTC, Yahoo: INTC) | Intel Corporation
# Retreiving fundamental data from yfinance...
#
# (28/116) | MCD (Google: NYSE:MCD, Yahoo: MCD) | McDonald's Corporation
# Retreiving fundamental data from yfinance...
#
# (29/116) | MSFT (Google: NASDAQ:MSFT, Yahoo: MSFT) | Microsoft Corporation
# Retreiving fundamental data from yfinance...
#
# (30/116) | NKE (Google: FRA:NKE, Yahoo: NKE.F) | NIKE Inc.
# Retreiving fundamental data from yfinance...
#
# (31/116) | PG (Google: NYSE:PG, Yahoo: PG) | The Procter & Gamble Company
# Retreiving fundamental data from yfinance...
#
# (32/116) | VZ (Google: NYSE:VZ, Yahoo: VZ) | Verizon Communications Inc.
# Retreiving fundamental data from yfinance...
#
# (33/116) | V (Google: NYSE:V, Yahoo: V) | Visa Inc.
# Retreiving fundamental data from yfinance...
#
# (34/116) | WMT (Google: FRA:WMT, Yahoo: WMT.F) | Walmart Inc.
# Retreiving fundamental data from yfinance...
#
# (35/116) | WBA (Google: NASDAQ:WBA, Yahoo: WBA) | Walgreens Boots Alliance Inc.
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (36/116) | DIS (Google: OTCMKTS:DIS, Yahoo: DIS) | The Walt Disney Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (37/116) | HON (Google: NYSE:HON, Yahoo: HON) | Honeywell International Inc.
# Retreiving fundamental data from yfinance...
#
# (38/116) | CRM (Google: NYSE:CRM, Yahoo: CRM) | salesforce.com Inc.
# Retreiving fundamental data from yfinance...
#
# (39/116) | DOW (Google: NYSE:DOW, Yahoo: DOW) | Dow Inc.
# Retreiving fundamental data from yfinance...
#
# (40/116) | AHT (Google: FRA:AHT, Yahoo: AHT.F) | Ashtead Group PLC
# Retreiving fundamental data from yfinance...
#
# (41/116) | AUTO (Google: FRA:AUTO, Yahoo: AUTO.F) | Auto Trader Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (42/116) | BDEV (Google: FRA:BDEV, Yahoo: BDEV.F) | Barratt Developments PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (43/116) | BKG (Google: FRA:BKG, Yahoo: BKG.F) | Berkeley Group Holdings/The
# Retreiving fundamental data from yfinance...
#
# (44/116) | BNZL (Google: LON:BNZL, Yahoo: BNZL.L) | Bunzl PLC
# Retreiving fundamental data from yfinance...
#
# (45/116) | BRBY (Google: LON:BRBY, Yahoo: BRBY.L) | Burberry Group PLC
# Retreiving fundamental data from yfinance...
#
# (46/116) | CPG (Google: LON:CPG, Yahoo: CPG.L) | Compass Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (47/116) | CRDA (Google: LON:CRDA, Yahoo: CRDA.L) | Croda International PLC
# Retreiving fundamental data from yfinance...
#
# (48/116) | SMDS (Google: LON:SMDS, Yahoo: SMDS.L) | DS Smith PLC
# Retreiving fundamental data from yfinance...
#
# (49/116) | EXPN (Google: LON:EXPN, Yahoo: EXPN.L) | Experian PLC
# Retreiving fundamental data from yfinance...
#
# (50/116) | HLMA (Google: LON:HLMA, Yahoo: HLMA.L) | Halma PLC
# Retreiving fundamental data from yfinance...
#
# (51/116) | INF (Google: LON:INF, Yahoo: INF.L) | Informa PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (52/116) | IHG (Google: LON:IHG, Yahoo: IHG.L) | InterContinental Hotels Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (53/116) | IAG (Google: BME:IAG, Yahoo: IAG.MC) | International Consolidated Airlines Group SA
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (54/116) | ITRK (Google: LON:ITRK, Yahoo: ITRK.L) | Intertek Group PLC
# Retreiving fundamental data from yfinance...
#
# (55/116) | JMAT (Google: LON:JMAT, Yahoo: JMAT.L) | Johnson Matthey PLC
# Retreiving fundamental data from yfinance...
#
# (56/116) | KGF (Google: LON:KGF, Yahoo: KGF.L) | Kingfisher PLC
# Retreiving fundamental data from yfinance...
#
# (57/116) | MRO (Google: LON:MRO, Yahoo: MRO.L) | Melrose Industries PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (58/116) | NXT (Google: LON:NXT, Yahoo: NXT.L) | NEXT PLC
# Retreiving fundamental data from yfinance...
#
# (59/116) | OCDO (Google: LON:OCDO, Yahoo: OCDO.L) | Ocado Group PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (60/116) | PSON (Google: LON:PSON, Yahoo: PSON.L) | Pearson PLC
# Retreiving fundamental data from yfinance...
#
# (61/116) | PSN (Google: LON:PSN, Yahoo: PSN.L) | Persimmon PLC
# Retreiving fundamental data from yfinance...
#
# (62/116) | REL (Google: LON:REL, Yahoo: REL.L) | RELX PLC
# Retreiving fundamental data from yfinance...
#
# (63/116) | RTO (Google: FRA:RTO, Yahoo: RTO.F) | Rentokil Initial PLC
# Retreiving fundamental data from yfinance...
#
# (64/116) | RMV (Google: LON:RMV, Yahoo: RMV.L) | Rightmove PLC
# Retreiving fundamental data from yfinance...
#
# (65/116) | SGE (Google: LON:SGE, Yahoo: SGE.L) | The Sage Group PLC
# Retreiving fundamental data from yfinance...
#
# (66/116) | SBRY (Google: LON:SBRY, Yahoo: SBRY.L) | J Sainsbury PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (67/116) | SMT (Google: LON:SMT, Yahoo: SMT.L) | Scottish Mortgage Investment Trust PLC
# Retreiving fundamental data from yfinance...
#
# (68/116) | SVT (Google: LON:SVT, Yahoo: SVT.L) | Severn Trent PLC
# Retreiving fundamental data from yfinance...
#
# (69/116) | SMIN (Google: LON:SMIN, Yahoo: SMIN.L) | Smiths Group PLC
# Retreiving fundamental data from yfinance...
#
# (70/116) | SKG (Google: LON:SKG, Yahoo: SKG.L) | Smurfit Kappa Group PLC
# Retreiving fundamental data from yfinance...
#
# (71/116) | SPX (Google: LON:SPX, Yahoo: SPX.L) | Spirax-Sarco Engineering PLC
# Retreiving fundamental data from yfinance...
#
# (72/116) | TSCO (Google: LON:TSCO, Yahoo: TSCO.L) | Tesco PLC
# Retreiving fundamental data from yfinance...
#
# (73/116) | VOD (Google: NASDAQ:VOD, Yahoo: VOD) | Vodafone Group PLC
# Retreiving fundamental data from yfinance...
#
# (74/116) | WTB (Google: LON:WTB, Yahoo: WTB.L) | Whitbread PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (75/116) | MRW (Google: LON:MRW, Yahoo: MRW.L) | Wm Morrison Supermarkets PLC
# Retreiving fundamental data from yfinance...
#
# (76/116) | WPP (Google: LON:WPP, Yahoo: WPP.L) | WPP PLC
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (77/116) | FERG (Google: LON:FERG, Yahoo: FERG.L) | Ferguson PLC
# Retreiving fundamental data from yfinance...
#
# (78/116) | AVV (Google: LON:AVV, Yahoo: AVV.L) | AVEVA Group plc
# Retreiving fundamental data from yfinance...
#
# (79/116) | JD (Google: LON:JD, Yahoo: JD.L) | JD Sports Fashion plc
# Retreiving fundamental data from yfinance...
#
# (80/116) | PNN (Google: LON:PNN, Yahoo: PNN.L) | Pennon Group plc
# Retreiving fundamental data from yfinance...
#
# (81/116) | SSE (Google: LON:SSE, Yahoo: SSE.L) | SSE plc
# Retreiving fundamental data from yfinance...
#
# (82/116) | ADBE (Google: NASDAQ:ADBE, Yahoo: ADBE) | Adobe Inc.
# Retreiving fundamental data from yfinance...
#
# (83/116) | GOOGL (Google: NASDAQ:GOOGL, Yahoo: GOOGL) | Alphabet Inc.
# Retreiving fundamental data from yfinance...
#
# (84/116) | AMZN (Google: NASDAQ:AMZN, Yahoo: AMZN) | Amazon.com Inc.
# Retreiving fundamental data from yfinance...
#
# (85/116) | CHTR (Google: NASDAQ:CHTR, Yahoo: CHTR) | Charter Communications Inc.
# Retreiving fundamental data from yfinance...
#
# (86/116) | CMCSA (Google: NASDAQ:CMCSA, Yahoo: CMCSA) | Comcast Corporation
# Retreiving fundamental data from yfinance...
#
# (87/116) | COST (Google: NASDAQ:COST, Yahoo: COST) | Costco Wholesale Corporation
# Retreiving fundamental data from yfinance...
#
# (88/116) | FB (Google: NASDAQ:FB, Yahoo: FB) | Facebook Inc.
# Retreiving fundamental data from yfinance...
#
# (89/116) | NFLX (Google: NASDAQ:NFLX, Yahoo: NFLX) | Netflix Inc.
# Retreiving fundamental data from yfinance...
#
# (90/116) | NVDA (Google: NASDAQ:NVDA, Yahoo: NVDA) | NVIDIA Corporation
# Retreiving fundamental data from yfinance...
#
# (91/116) | PYPL (Google: NASDAQ:PYPL, Yahoo: PYPL) | PayPal Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (92/116) | QCOM (Google: NASDAQ:QCOM, Yahoo: QCOM) | Qualcomm Inc.
# Retreiving fundamental data from yfinance...
#
# (93/116) | SBUX (Google: NASDAQ:SBUX, Yahoo: SBUX) | Starbucks Corporation
# Retreiving fundamental data from yfinance...
#
# (94/116) | TSLA (Google: NASDAQ:TSLA, Yahoo: TSLA) | Tesla Inc.
# Retreiving fundamental data from yfinance...
#
# (95/116) | TXN (Google: NASDAQ:TXN, Yahoo: TXN) | Texas Instruments Inc.
# Retreiving fundamental data from yfinance...
#
# (96/116) | ACN (Google: NYSE:ACN, Yahoo: ACN) | Accenture PLC
# Retreiving fundamental data from yfinance...
#
# (97/116) | T (Google: NYSE:T, Yahoo: T) | AT&T Inc
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (98/116) | BKNG (Google: NASDAQ:BKNG, Yahoo: BKNG) | Booking Holdings Inc.
# Retreiving fundamental data from yfinance...
#
# (99/116) | CL (Google: NYSE:CL, Yahoo: CL) | Colgate-Palmolive Company
# Retreiving fundamental data from yfinance...
#
# (100/116) | DUK (Google: NYSE:DUK, Yahoo: DUK) | Duke Energy Corporation
# Retreiving fundamental data from yfinance...
#
# (101/116) | EMR (Google: FRA:EMR, Yahoo: EMR.F) | Emerson Electric Co.
# Retreiving fundamental data from yfinance...
#
# (102/116) | EXC (Google: NYSE:EXC, Yahoo: EXC) | Exelon Corporation
# Retreiving fundamental data from yfinance...
#
# (103/116) | FDX (Google: FRA:FDX, Yahoo: FDX.F) | FedEx Corporation
# Retreiving fundamental data from yfinance...
#
# (104/116) | F (Google: NYSE:F, Yahoo: F) | Ford Motor Company
# Retreiving fundamental data from yfinance...
#
# (105/116) | GE (Google: NYSE:GE, Yahoo: GE) | General Electric Company
# Retreiving fundamental data from yfinance...
# ERROR: 'trailingPE'
# An error occurred while trying to get the information!
#
# (106/116) | LOW (Google: NYSE:LOW, Yahoo: LOW) | Lowe's Companies Inc.
# Retreiving fundamental data from yfinance...
#
# (107/116) | MA (Google: NYSE:MA, Yahoo: MA) | Mastercard Inc.
# Retreiving fundamental data from yfinance...
#
# (108/116) | NEE (Google: NYSE:NEE, Yahoo: NEE) | NextEra Energy Inc.
# Retreiving fundamental data from yfinance...
#
# (109/116) | ORCL (Google: NYSE:ORCL, Yahoo: ORCL) | Oracle Corporation
# Retreiving fundamental data from yfinance...
#
# (110/116) | RTN (Google: NYSE:RTN, Yahoo: RTN) | Raytheon Company
# Retreiving fundamental data from yfinance...
# ERROR: 'longBusinessSummary'
# An error occurred while trying to get the information!
#
# (111/116) | SO (Google: NYSE:SO, Yahoo: SO) | Southern Company
# Retreiving fundamental data from yfinance...
#
# (112/116) | TGT (Google: NYSE:TGT, Yahoo: TGT) | Target Corporation
# Retreiving fundamental data from yfinance...
#
# (113/116) | UNP (Google: FRA:UNP, Yahoo: UNP.F) | Union Pacific Corporation
# Retreiving fundamental data from yfinance...
#
# (114/116) | UPS (Google: NYSE:UPS, Yahoo: UPS) | United Parcel Service Inc.
# Retreiving fundamental data from yfinance...
#
# (115/116) | GD (Google: NYSE:GD, Yahoo: GD) | General Dynamics Corporation
# Retreiving fundamental data from yfinance...
#
# (116/116) | LMT (Google: NYSE:LMT, Yahoo: LMT) | Lockheed Martin Corporation
# Retreiving fundamental data from yfinance...

# %%
# Calculating percentiles
print('Calculating Percentiles...')

metrics = {
    'PriceToEarningsRatio': 'PriceToEarningsPercentile',
    'PriceToSalesRatio': 'PriceToSalesPercentile',
    'EV_EBITDA':'EV_EBITDAPercentile',
    'EV_R':'EV_RPercentile'
}

for row in so_dataframe.index:
    for metric in metrics.keys():
        if(metric == 'PriceToSalesRatio' or metric == 'EV_R'):
            so_dataframe.loc[row, metrics[metric]] = stats.percentileofscore(1 / so_dataframe[metric], 1 / so_dataframe.loc[row, metric])
        else:
            so_dataframe.loc[row, metrics[metric]] = stats.percentileofscore(so_dataframe[metric], so_dataframe.loc[row, metric])

# Scoring stocks
print('Scoring Stocks...')
for row in so_dataframe.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(so_dataframe.loc[row, metrics[metric]])
    so_dataframe.loc[row, 'Score'] = mean(value_percentiles)

# Sorting and selecting
result_df = so_dataframe[so_dataframe['Score'] >= 50].copy()
result_df.sort_values(by = 'Score', inplace = True, ascending=False)

skipped_count = initial_count - len(result_df)
now = DateTime.now()

print()
print(f'Scoring executed successfully at {now.hour}:{now.minute} | {total_stocks} listed | {errors} not found | {skipped_count} incomplete | {len(result_df)} selected')
# Out:
# Calculating Percentiles...
# Scoring Stocks...
#
# Scoring executed successfully at 15:4 | 116 listed | 21 not found | 43 incomplete | 52 selected

# %%
result_df
# Out:
#      Dow Inc.    DOW      NYSE:DOW          DOW
# 90               Target Corporation    TGT      NYSE:TGT          TGT
# 40               Intertek Group PLC   ITRK      LON:ITRK       ITRK.L
# 75                       Tesla Inc.   TSLA   NASDAQ:TSLA         TSLA
# 3                  Deutsche Post AG    DPW       FRA:DPW        DPW.F
# 70                     Netflix Inc.   NFLX   NASDAQ:NFLX         NFLX
# 78            Booking Holdings Inc.   BKNG   NASDAQ:BKNG         BKNG
# 54     Spirax-Sarco Engineering PLC    SPX       LON:SPX        SPX.L
# 8                        Siemens AG    SIE       FRA:SIE        SIE.F
# 55                        Tesco PLC   TSCO      LON:TSCO       TSCO.L
# 30              salesforce.com Inc.    CRM      NYSE:CRM          CRM
# 72             PayPal Holdings Inc.   PYPL   NASDAQ:PYPL         PYPL
# 85            Lowe's Companies Inc.    LOW      NYSE:LOW          LOW
# 93     General Dynamics Corporation     GD       NYSE:GD           GD
# 19              The Home Depot Inc.     HD       NYSE:HD           HD
# 39                        Halma PLC   HLMA      LON:HLMA       HLMA.L
# 38                     Experian PLC   EXPN      LON:EXPN       EXPN.L
# 6                         Linde PLC    LIN       FRA:LIN        LIN.F
# 80          Duke Energy Corporation    DUK      NYSE:DUK          DUK
# 5                           E.ON SE   EOAN      FRA:EOAN       EOAN.F
# 66      Charter Communications Inc.   CHTR   NASDAQ:CHTR         CHTR
# 36          Croda International PLC   CRDA      LON:CRDA       CRDA.L
# 9                     Volkswagen AG   VOW3      FRA:VOW3       VOW3.F
#
#                                           Description         Country  \
# 68  Costco Wholesale Corporation, together with it...   United States
# 57  Wm Morrison Supermarkets PLC operates retail s...  United Kingdom
# 0   adidas AG, together with its subsidiaries, des...         Germany
# 60  JD Sports Fashion plc engages in the retail of...  United Kingdom
# 92  United Parcel Service, Inc. provides letter an...   United States
# 41  Johnson Matthey Plc provides specialty chemica...  United Kingdom
# 84  Ford Motor Company designs, manufactures, mark...   United States
# 65  Amazon.com, Inc. engages in the retail sale of...   United States
# 58  Ferguson plc distributes plumbing and heating ...  United Kingdom
# 56  Vodafone Group Plc engages in telecommunicatio...  United Kingdom
# 28  Walmart Inc. engages in the operation of retai...   United States
# 24  NIKE, Inc., together with its subsidiaries, de...   United States
# 10  CRH plc, through its subsidiaries, manufacture...         Ireland
# 74  Starbucks Corporation, together with its subsi...   United States
# 43  NEXT plc engages in the retail of clothing, fo...  United Kingdom
# 47  Rentokil Initial plc, together with its subsid...  United Kingdom
# 37  DS Smith Plc provides packaging solutions, pap...  United Kingdom
# 32  Ashland Global Holdings Inc. provides specialt...  United Kingdom
# 34  Bunzl plc operates as a distribution and servi...  United Kingdom
# 17  Caterpillar Inc. manufactures and sells constr...   United States
# 1   Bayerische Motoren Werke AG, together with its...         Germany
# 82  Exelon Corporation, a utility services holding...   United States
# 77  Accenture plc, a professional services company...         Ireland
# 52  Smiths Group plc operates as a technology comp...  United Kingdom
# 13  Koninklijke Ahold Delhaize N.V. operates retai...     Netherlands
# 83  FedEx Corporation provides transportation, e-c...   United States
# 44  Pearson plc provides educational materials and...  United Kingdom
# 59  AVEVA Group plc, through its subsidiaries, pro...  United Kingdom
# 2   Daimler AG, together its subsidiaries, develop...         Germany
# 31  Dow Inc. provides various materials science so...   United States
# 90  Target Corporation operates as a general merch...   United States
# 40  Intertek Group plc provides quality assurance ...  United Kingdom
# 75  Tesla, Inc. designs, develops, manufactures, l...   United States
# 3   Deutsche Post AG operates as a mail and logist...         Germany
# 70  Netflix, Inc. provides entertainment services....   United States
# 78  Booking Holdings Inc. provides travel and rest...   United States
# 54  Spirax-Sarco Engineering plc provides engineer...  United Kingdom
# 8   Siemens Aktiengesellschaft, a technology compa...         Germany
# 55  Tesco PLC, together with its subsidiaries, eng...  United Kingdom
# 30  salesforce.com, inc. develops enterprise cloud...   United States
# 72  PayPal Holdings, Inc. operates as a technology...   United States
# 85  Lowe's Companies, Inc., together with its subs...   United States
# 93  General Dynamics Corporation operates as an ae...   United States
# 19  The Home Depot, Inc. operates as a home improv...   United States
# 39  Halma plc provides technology solutions in the...  United Kingdom
# 38  Experian plc, together with its subsidiaries, ...         Ireland
# 6   Linde plc operates as an industrial gas compan...  United Kingdom
# 80  Duke Energy Corporation, together with its sub...   United States
# 5   E.ON SE operates as an energy company in Germa...         Germany
# 66  Charter Communications, Inc. operates as a bro...   United States
# 36  Croda International Plc creates, makes, and se...  United Kingdom
# 9   Volkswagen AG manufactures and sells automobil...         Germany
#
#                          Indices  \
# 68  NASDAQ 100, S&P 100, S&P 500
# 57                      FTSE 100
# 0             DAX, EURO STOXX 50
# 60                      FTSE 100
# 92              S&P 100, S&P 500
# 41                      FTSE 100
# 84              S&P 100, S&P 500
# 65  NASDAQ 100, S&P 100, S&P 500
# 58                      FTSE 100
# 56                      FTSE 100
# 28   DOW JONES, S&P 100, S&P 500
# 24   DOW JONES, S&P 100, S&P 500
# 10       EURO STOXX 50, FTSE 100
# 74  NASDAQ 100, S&P 100, S&P 500
# 43                      FTSE 100
# 47                      FTSE 100
# 37                      FTSE 100
# 32                      FTSE 100
# 34                      FTSE 100
# 17   DOW JONES, S&P 100, S&P 500
# 1             DAX, EURO STOXX 50
# 82  NASDAQ 100, S&P 100, S&P 500
# 77              S&P 100, S&P 500
# 52                      FTSE 100
# 13            AEX, EURO STOXX 50
# 83              S&P 100, S&P 500
# 44                      FTSE 100
# 59                      FTSE 100
# 2             DAX, EURO STOXX 50
# 31   DOW JONES, S&P 100, S&P 500
# 90              S&P 100, S&P 500
# 40                      FTSE 100
# 75  NASDAQ 100, S&P 100, S&P 500
# 3             DAX, EURO STOXX 50
# 70  NASDAQ 100, S&P 100, S&P 500
# 78  NASDAQ 100, S&P 100, S&P 500
# 54                      FTSE 100
# 8             DAX, EURO STOXX 50
# 55                      FTSE 100
# 30   DOW JONES, S&P 100, S&P 500
# 72  NASDAQ 100, S&P 100, S&P 500
# 85              S&P 100, S&P 500
# 93              S&P 100, S&P 500
# 19   DOW JONES, S&P 100, S&P 500
# 39                      FTSE 100
# 38                      FTSE 100
# 6    DAX, EURO STOXX 50, S&P 500
# 80              S&P 100, S&P 500
# 5             DAX, EURO STOXX 50
# 66  NASDAQ 100, S&P 100, S&P 500
# 36                      FTSE 100
# 9             DAX, EURO STOXX 50
#
#                                               Sectors      Price  \
# 68  Diversified Retail, Retailers, Discount Stores...    412.370
# 57  Consumer Non-Cyclicals, Food & Drug Retailing,...    264.900
# 0   Cyclical Consumer Products, Footwear, Textiles...    315.950
# 60                                             Retail    957.000
# 92  Industrial Goods, Industrials, Aerospace & Def...    213.920
# 41    Specialty Chemicals, Basic Materials, Chemicals   3162.000
# 84  Auto & Truck Manufacturers, Automobiles & Auto...     14.480
# 65  Diversified Retail, Retailers, Department Stor...   3719.340
# 58                                 Building materials  10350.000
# 56  Telecommunications Services, Wireless Telecomm...     16.670
# 28  Consumer Non-Cyclicals, Food & Drug Retailing,...    118.740
# 24  Cyclical Consumer Products, Footwear, Textiles...    135.180
# 10  Construction Materials, Mineral Resources, Bas...     50.440
# 74  Hotels & Entertainment Services, Restaurants &...    117.470
# 43  Other Specialty Retailers, Retailers, Specialt...   7840.000
# 47  Business Support Services, Industrials, Profes...     29.200
# 37  Paper Packaging, Basic Materials, Containers &...    427.200
# 32  Business Support Services, Industrials, Profes...     72.000
# 34  Industrials, Diversified Trading & Distributin...   2556.000
# 17  Industrial Goods, Industrials, Heavy Machinery...    217.420
# 1   Automotive, Auto & Truck Manufacturers, Automo...     87.810
# 82  Electric Utilities, Electric Utilities & IPPs,...     44.910
# 77  Technology, Software & IT Services, IT Service...    312.620
# 52              Industrials, Industrial Conglomerates   1621.000
# 13  Consumer Non-Cyclicals, Food & Drug Retailing,...     25.340
# 83  Industrials, Air Freight & Courier Services, F...    249.600
# 44  Media & Publishing, Consumer Publishing, Cycli...    821.400
# 59  Software, Enterprise Asset Management, Manufac...   3924.000
# 2   Automotive, Auto & Truck Manufacturers, Automo...     73.090
# 31                                          Chemicals     63.080
# 90  Diversified Retail, Retailers, Discount Stores...    248.580
# 40  Business Support Services, Industrials, Profes...   5602.000
# 75  Auto & Truck Manufacturers, Automobiles & Auto...    656.950
# 3   Industrials, Air Freight & Courier Services, F...     58.430
# 70  Technology, Software & IT Services, Internet S...    535.980
# 78  Hotels & Entertainment Services, Leisure & Rec...   2194.990
# 54  Industrial Goods, Industrials, Machinery, Equi...  14010.000
# 8               Industrials, Industrial Conglomerates    132.540
# 55  Consumer Non-Cyclicals, Food & Drug Retailing,...    237.700
# 30  Technology, Software & IT Services, IT Service...    245.060
# 72  Technology, Software & IT Services, Internet S...    300.210
# 85  Retailers, Specialty Retailers, Home Improveme...    195.330
# 93                                 Aerospace, Defense    190.220
# 19  Retailers, Specialty Retailers, Home Improveme...    322.090
# 39  Industrial Goods, Industrials, Machinery, Equi...   2775.000
# 38  Professional Information Services, Industrials...   2938.000
# 6     Commodity Chemicals, Basic Materials, Chemicals    247.350
# 80  Electric Utilities, Electric Utilities & IPPs,...    100.660
# 5                                              Energy     10.088
# 66  Media & Publishing, Cyclical Consumer Services...    736.470
# 36    Specialty Chemicals, Basic Materials, Chemicals   7638.000
# 9   Automotive, Auto & Truck Manufacturers, Automo...    212.800
#
#     PriceToEarningsRatio PriceToEarningsPercentile  PriceToSalesRatio  \
# 68             42.168930                   73.4043           0.977768
# 57             66.225000                   90.4255           0.362737
# 0              64.400734                   88.2979           2.983671
# 60             41.608696                   71.2766           1.600814
# 92             36.122932                   64.8936           2.094770
# 41             29.718044                   47.8723           0.390449
# 84             14.567404                   11.7021           0.447873
# 65             70.761010                   92.5532           4.475347
# 58             34.147144                   57.4468           1.042313
# 56            333.400000                   97.8723           1.060519
# 28             30.137054                   51.0638           0.588718
# 24             75.435265                    93.617           5.546954
# 10             35.571228                   63.8298           1.430703
# 74            138.362780                   96.8085           5.805337
# 43             35.331230                   61.7021           2.949073
# 47             49.914530                   76.5957           4.060419
# 37             30.297873                   52.1277           0.981738
# 32             37.994724                   69.1489           1.906043
# 34             19.922058                   21.2766           0.852491
# 17             34.764950                   60.6383           2.769764
# 1              15.324607                   13.8298           0.558448
# 82             40.459457                   70.2128           1.283861
# 77             36.996450                   67.0213           4.350471
# 52             25.977564                   40.4255           2.613978
# 13             20.601625                   27.6596           0.347832
# 83             26.232265                   41.4894           0.792023
# 44             20.034147                   22.3404           1.828588
# 59            347.256620                   98.9362          14.405059
# 2               9.995897                   6.38298           0.495801
# 31             23.830751                   38.2979           1.159051
# 90             20.295559                   25.5319           1.253054
# 40             36.758533                   65.9574           3.297675
# 75            658.266540                       100          17.608784
# 3              19.126022                   18.0851           1.027363
# 70             64.865060                   89.3617           9.004938
# 78            128.354480                   95.7447          15.951582
# 54             59.667800                    87.234           8.659809
# 8              18.133806                   17.0213           1.813554
# 55              2.949132                   3.19149           0.317485
# 30             55.949768                   82.9787          10.111965
# 72             68.416130                   91.4894          15.421124
# 85             21.305628                   30.8511           1.463546
# 93             17.292727                   15.9574           1.411988
# 19             23.479370                   35.1064           2.422819
# 39             51.772390                   78.7234           7.992071
# 38             56.391556                   84.0426           5.017018
# 6              53.331177                   80.8511           4.636107
# 80             58.557304                   86.1702           3.301471
# 5              11.662428                   7.44681           0.421809
# 66             41.624930                   72.3404           2.842553
# 36             49.341084                   75.5319           7.664865
# 9               9.547739                   5.31915           0.548834
#
#    PriceToSalesPercentile EV_EBITDA EV_EBITDAPercentile    EV_R  \
# 68                84.0426    20.052             63.8298   0.932
# 57                96.8085    11.203             22.3404   0.499
# 0                 48.9362    31.882             81.9149   3.048
# 60                70.2128    16.822              56.383   1.709
# 92                 62.766    21.231             70.2128   2.194
# 41                95.7447    10.171             18.0851   0.431
# 84                 93.617    21.708             71.2766   1.422
# 65                38.2979    32.918             84.0426   4.490
# 58                80.8511    11.846             29.7872   1.018
# 56                79.7872     9.491             11.7021   2.613
# 28                89.3617      9.51             13.2979   0.670
# 24                28.7234    34.012             85.1064   4.583
# 10                73.4043    11.879             30.8511   1.688
# 74                27.6596    44.572             91.4894   6.346
# 43                51.0638    26.478             78.7234   3.503
# 47                41.4894    21.159             69.1489   3.939
# 37                82.9787      9.51             13.2979   1.278
# 32                63.8298    12.044             31.9149   2.500
# 34                85.1064     12.06             32.9787   0.960
# 17                 56.383    18.818             60.6383   3.417
# 1                 90.4255     14.33             44.6809   1.464
# 82                75.5319     9.937             17.0213   2.504
# 77                39.3617    23.745             75.5319   3.945
# 52                57.4468    21.118             68.0851   3.041
# 13                97.8723     7.592             4.25532   0.509
# 83                86.1702     8.257             6.38298   1.156
# 44                65.9574    18.793             59.5745   2.019
# 59                10.6383    74.339             97.8723  14.090
# 2                 92.5532    12.299             35.1064   1.283
# 31                78.7234    10.944             21.2766   1.535
# 90                76.5957    11.538             27.6596   1.272
# 40                46.8085    16.506             53.1915   3.516
# 75                7.44681    138.28             98.9362  17.510
# 3                 81.9149    11.488             26.5957   1.203
# 70                15.9574    42.652             89.3617   9.228
# 78                8.51064   172.747                 100  16.850
# 54                18.0851    34.705             86.1702   8.500
# 8                 67.0213    16.873             57.4468   2.242
# 55                98.9362     9.334             10.6383   0.499
# 30                14.8936    61.911             94.6809   9.629
# 72                9.57447    67.031             95.7447  14.582
# 85                71.2766    11.418             25.5319   1.671
# 93                74.4681    12.962             40.4255   1.719
# 19                59.5745    14.774             46.8085   2.609
# 39                22.3404    32.148             82.9787   8.028
# 38                32.9787    15.699             52.1277   5.301
# 6                 36.1702    15.567                  50   5.081
# 80                45.7447      13.1             41.4894   6.167
# 5                 94.6809     8.718             8.51064   0.992
# 66                55.3191    12.094             34.0426   4.605
# 36                23.4043    29.214             80.8511   7.768
# 9                 91.4894     9.909             15.9574   1.170
#
#    EV_RPercentile    Score
# 68         93.617  78.7234
# 57        98.4043  76.9947
# 0         60.6383  69.9468
# 60        76.5957   68.617
# 92        71.2766  67.2872
# 41            100  65.4255
# 84        82.9787  64.8936
# 65         43.617  64.6277
# 58        90.4255  64.6277
# 56        63.8298  63.2979
# 28        95.7447   62.367
# 24        41.4894   62.234
# 10        77.6596  61.4362
# 74        28.7234  61.1702
# 43        51.0638  60.6383
# 47        47.8723  58.7766
# 37        85.1064  58.3777
# 32        67.0213  57.9787
# 34        92.5532  57.9787
# 17        54.2553  57.9787
# 1         80.8511  57.4468
# 82        65.9574  57.1809
# 77        46.8085  57.1809
# 52        61.7021  56.9149
# 13        96.8085  56.6489
# 83        89.3617  55.8511
# 44        73.4043  55.3191
# 59        11.7021  54.7872
# 2         84.0426  54.5213
# 31        79.7872  54.5213
# 90        86.1702  53.9894
# 40             50  53.9894
# 75        8.51064  53.7234
# 3          87.234  53.4574
# 70        19.1489  53.4574
# 78        9.57447  53.4574
# 54        20.2128  52.9255
# 8         70.2128  52.9255
# 55        98.4043  52.7926
# 30        18.0851  52.6596
# 72        10.6383  51.8617
# 85        78.7234  51.5957
# 93        75.5319  51.5957
# 19        64.8936  51.5957
# 39        21.2766  51.3298
# 38        36.1702  51.3298
# 6          37.234  51.0638
# 80        29.7872  50.7979
# 5         91.4894  50.5319
# 66        40.4255  50.5319
# 36        22.3404  50.5319
# 9         88.2979   50.266

# %%
with open("../dist/md.txt", "a", encoding='utf-8') as f:
    md_df = result_df[['Company','Symbol','Symbol_Yahoo', 'PriceToEarningsRatio','PriceToEarningsPercentile','PriceToSalesRatio','PriceToSalesPercentile','EV_EBITDA','EV_EBITDAPercentile','EV_R','EV_RPercentile','Score']]
    md_df.columns = ['Company','Symbol','Yahoo Symbol', 'P/E', 'P/E PC', 'P/S','P/S PC', 'EV/EBITDA','EV/EBITDA PC', 'EV/R','EV/R PC','Score']
    f.write(md_df.to_markdown(index=False))

# %%
writer = pd.ExcelWriter('../dist/market_stock_value_scoring.xlsx', engine='xlsxwriter')
result_df.to_excel(writer, sheet_name='Value Scoring', index = False)

# Defining Excel columns formats and templates
background_light_color = '#ffffff'
background_dark_color = '#eeeeee'
background_accent_color = '#0086CD'
black_color = '#000000'
white_color = '#ffffff'

string_template = writer.book.add_format(
        {
            'font_color': black_color,
            'bg_color': background_light_color,
            'border': 0
        }
    )

dollar_template = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': black_color,
            'bg_color': background_light_color,
            'border': 0
        }
    )

float_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': black_color,
            'bg_color': background_light_color,
            'border': 0
        }
    )

percentile_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': black_color,
            'bg_color': background_dark_color,
            'border': 0
        }
    )

score_template = writer.book.add_format(
        {
            'num_format':'0.000',
            'font_color': white_color,
            'bg_color': background_accent_color,
            'border': 0
        }
    )

print('Saving in Excel...\n')

column_formats = {
    'A': ['Stock', string_template],
    'B': ['Symbol', string_template],
    'C': ['Symbol_Google', string_template],
    'D': ['Symbol_Yahoo', string_template],
    'E': ['Description', string_template],
    'F': ['Country', string_template],
    'G': ['Indices', string_template],
    'H': ['Sectors', string_template],
    'I': ['Price', dollar_template],
    'J': ['PriceToEarningsRatio', float_template],
    'K': ['PriceToEarningsPercentile', percentile_template],
    'L': ['PriceToSalesRatio', float_template],
    'M': ['PriceToSalesPercentile', percentile_template],
    'N': ['EV_EBITDA', float_template],
    'O': ['EV_EBITDAPercentile', percentile_template],
    'P': ['EV_R', float_template],
    'Q': ['EV_RPercentile', percentile_template],
    'R': ['Score', score_template]
}

for column in column_formats.keys():
    writer.sheets['Value Scoring'].set_column(f'{column}:{column}', 25, column_formats[column][1])
    writer.sheets['Value Scoring'].write(f'{column}1', column_formats[column][0], column_formats[column][1])

writer.save()
# Out:
# Saving in Excel...
